# %%
import sys
sys.path.append('../')

import plyvel
import pandas as pd
from src import data_io

# %%
bids_df = data_io.load_bids(small=False)

# %%
db = plyvel.DB('/media/raid_arr/data/fb4/bids.lvldb', 
               create_if_missing=True)

# %%
def fill_lvldb(bid_row):

# %%
bids_df.apply(fill_lvldb, axis=1)

# %%
bids_df
# Out:
#           bid_id                              bidder_id auction  \
# 0              0  8dac2b259fd1c6d1120e519fb1ac14fbqvax8   ewmzr
# 1              1  668d393e858e8126275433046bbd35c6tywop   aeqok
# 2              2  aa5f360084278b35d746fa6af3a7a1a5ra3xe   wa00e
# 3              3  3939ac3ef7d472a59a9c5f893dd3e39fh9ofi   jefix
# 4              4  8393c48eaf4b8fa96886edc7cf27b372dsibi   jefix
# 5              5  e8291466de91b0eb4e1515143c7f74dexy2yr   3vi4t
# 6              6  eef4c687daf977f64fc1d08675c44444raj3s   kjlzx
# 7              7  ab056855c9ca9d36390feae1fa485883issyg   f5f6k
# 8              8  d600dc03b11e7d782e1e4dae091b084a1h5ch   h7jjx
# 9              9  a58ace8b671a7531c88814bc86b2a34cf0crb   3zpkj
# 10            10  a58ace8b671a7531c88814bc86b2a34cf0crb   z6j8b
# 11            11  fe37b8b29d26021ea9462bcc7c5bf5c2pbya7   jefix
# 12            12  990db0dcdb665fb8fda5845b3e5d63082mbqq   jefix
# 13            13  7e34a26c4c339e875997f4b9239d2b5fscng4   nbx39
# ...

# %%
q
# Out:
# bid_id                                             0
# bidder_id      8dac2b259fd1c6d1120e519fb1ac14fbqvax8
# auction                                        ewmzr
# merchandise                                  jewelry
# device                                        phone0
# time                                9759243157894736
# country                                           us
# ip                                     69.166.231.58
# url                                  vasstdc27m7nks3
# Name: 0, dtype: object

# %%
from src.containers import *

bid = Bid(**q)

# %%
bids_df = pd.io.parsers.read_csv(data_io.BIDS_PATH, index_col=0)

# %%
bids_df.loc[]
# Out:
#                                      bidder_id auction       merchandise  \
# bid_id
# 0        8dac2b259fd1c6d1120e519fb1ac14fbqvax8   ewmzr           jewelry
# 1        668d393e858e8126275433046bbd35c6tywop   aeqok         furniture
# 2        aa5f360084278b35d746fa6af3a7a1a5ra3xe   wa00e        home goods
# 3        3939ac3ef7d472a59a9c5f893dd3e39fh9ofi   jefix           jewelry
# 4        8393c48eaf4b8fa96886edc7cf27b372dsibi   jefix           jewelry
# 5        e8291466de91b0eb4e1515143c7f74dexy2yr   3vi4t            mobile
# 6        eef4c687daf977f64fc1d08675c44444raj3s   kjlzx            mobile
# 7        ab056855c9ca9d36390feae1fa485883issyg   f5f6k        home goods
# 8        d600dc03b11e7d782e1e4dae091b084a1h5ch   h7jjx        home goods
# 9        a58ace8b671a7531c88814bc86b2a34cf0crb   3zpkj    sporting goods
# 10       a58ace8b671a7531c88814bc86b2a34cf0crb   z6j8b    sporting goods
# 11       fe37b8b29d26021ea9462bcc7c5bf5c2pbya7   jefix           jewelry
# ...
