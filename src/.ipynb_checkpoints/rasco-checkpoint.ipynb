# %%
import os
import numpy as np
import pandas as pd
from time import time
import sys
import copy
import pdb
import cPickle as pickle
import gzip

from transformers import *
from sklearn.preprocessing import StandardScaler
from sklearn.cross_validation import StratifiedKFold
from sklearn.metrics import log_loss, roc_auc_score
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, ExtraTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
mode ='final'

# Load Data
import transformers
reload(transformers)
from transformers import *

pp = make_union(
    IdentityTformer(), 
    make_pipeline(AddTformer(1), BoxCoxTformer())
)

# Data
X = np.load('../data/X.npy')
y = np.load('../data/y.npy')
X_test = np.load('../data/X_test.npy')

pp.fit(np.r_[X, X_test])
X = pp.transform(X)
X_test = pp.transform(X_test)

k = 4
skf = StratifiedKFold(y, n_folds=k, random_state=0)

ind_train, ind_valid = list(iter(skf))[3]
X_train, X_valid = X[ind_train], X[ind_valid]
y_train, y_valid = y[ind_train], y[ind_valid]

n_feats = X_train.shape[1]
n_classes = len(np.unique(y_train))

# TO TRAIN ON ALL
if mode == 'final':
    X_train = X.copy()
    y_train = y.copy()

# %%
def shuffle_unison(a, b):
    """ Shuffles same-length arrays `a` and `b` in unison"""
    c = np.c_[a.reshape(len(a), -1), b.reshape(len(b), -1)]
    np.random.shuffle(c)
    return c[:, :a.size//len(a)].reshape(a.shape), c[:, a.size//len(a):].reshape(b.shape)

# %%
# RASCO PARAMS
m = round(0.5 * n_feats)    # Size of subspace (# feats to use)
K = 128    # num of classifiers to use
J = 160    # num iterations

sub_sps = [np.random.permutation(n_feats)[:m] 
               for k in range(K)]

# %%
# Init
# Consider dedicated training sets per model
# L_X = [X_train] * K
# L_y = [y_train] * K
L_X = X_train
L_y = y_train
U_X = X_test

prob_thresh = 0.999
thresh_decay = 0.0001
prob_thresh_min = 0.975
# ~160 iterations seems be the peak
# ~0.003 increase in AUC
# maybe limit the number of transfer per iteration to 1?

# %%
from joblib import Parallel, delayed

# clf0 = DecisionTreeClassifier
clf0 = ExtraTreeClassifier
clf1 = ExtraTreeClassifier

# clf = ExtraTreeClassifier
# clf = RandomForestClassifier

def train_model(X, y):
    model = clf()
    return model.fit(X, y)

def train_predict_model(X, y, U, val, s_i):
    if s_i < K/2:
        model = clf0(min_samples_leaf=8,
                           min_samples_split=7,
                           criterion='entropy',
                           max_depth=None,)
    else:
        model = clf1(min_samples_leaf=8,
                           min_samples_split=7,
                           criterion='entropy',
                           max_depth=None,)
    model.fit(X, y)
    U_pred = model.predict_proba(U)
    val_pred = model.predict_proba(val)
    
    return model, U_pred, val_pred

# %%
score_list = []
score_fn = roc_auc_score
transfer_counts = []
for j in range(J):
    print 'Iter # %d' % j
    print 'Winner thresh:', prob_thresh
    # Subspace creation
    val_preds = []
    
    ret_iter = Parallel(n_jobs=-1)(
        delayed(train_predict_model)(
            L_X[:, sub_sp], L_y, 
            U_X[:, sub_sp], 
            X_valid[:, sub_sp],
            s_i,
        ) 
        for s_i, sub_sp in enumerate(sub_sps))
    
    models, U_preds, val_preds = zip(*ret_iter)
    val_pred_ens = np.array(val_preds).mean(axis=0)
    score_ens = score_fn(y_valid, val_pred_ens[:, 1])
    score_list.append(score_ens)
    print 'Ensemble score:', score_ens
        
    U_pred_avg = np.array(U_preds).mean(axis=0)
    max_probs = U_pred_avg.max(axis=1)
    U_y_pred = np.argmax(U_pred_avg, axis=1)
    
    win_inds = max_probs > prob_thresh
    L_X, L_y = shuffle_unison(
            np.r_[L_X, U_X[win_inds, :]],
            np.r_[L_y, U_y_pred[win_inds]],)
    
    U_X = np.delete(U_X, np.where(win_inds), axis=0)
    print 'Transferred unlabeled observations: %d' % win_inds.sum()
    print 'Transfer distribution:', [list(U_y_pred[win_inds]).count(cc) 
                                     for cc in range(n_classes)]
    transfer_counts.append(win_inds.sum())
    print 'Cumulative transfer:', np.array(transfer_counts).sum()
    
    if not win_inds.sum():
        prob_thresh -= thresh_decay
    sys.stdout.flush()
# Out:
# Iter # 0
# Winner thresh: 0.999
# Ensemble score: 0.971823899371
# Transferred unlabeled observations: 440
# Transfer distribution: [440, 0]
# Cumulative transfer: 440
# Iter # 1
# Winner thresh: 0.999
# Ensemble score: 0.971823899371
# Transferred unlabeled observations: 230
# Transfer distribution: [230, 0]
# Cumulative transfer: 670
# Iter # 2
# Winner thresh: 0.999
# Ensemble score: 0.970649895178
# Transferred unlabeled observations: 78
# Transfer distribution: [78, 0]
# Cumulative transfer: 748
# Iter # 3
# Winner thresh: 0.999
# Ensemble score: 0.97106918239
# Transferred unlabeled observations: 47
# Transfer distribution: [47, 0]
# Cumulative transfer: 795
# Iter # 4
# Winner thresh: 0.999
# Ensemble score: 0.970482180294
# Transferred unlabeled observations: 72
# Transfer distribution: [72, 0]
# Cumulative transfer: 867
# Iter # 5
# Winner thresh: 0.999
# Ensemble score: 0.969895178197
# Transferred unlabeled observations: 36
# Transfer distribution: [36, 0]
# Cumulative transfer: 903
# Iter # 6
# Winner thresh: 0.999
# Ensemble score: 0.971153039832
# Transferred unlabeled observations: 15
# Transfer distribution: [15, 0]
# Cumulative transfer: 918
# Iter # 7
# Winner thresh: 0.999
# Ensemble score: 0.97106918239
# Transferred unlabeled observations: 20
# Transfer distribution: [20, 0]
# Cumulative transfer: 938
# Iter # 8
# Winner thresh: 0.999
# Ensemble score: 0.970817610063
# Transferred unlabeled observations: 24
# Transfer distribution: [24, 0]
# Cumulative transfer: 962
# Iter # 9
# Winner thresh: 0.999
# Ensemble score: 0.969727463312
# Transferred unlabeled observations: 7
# Transfer distribution: [7, 0]
# Cumulative transfer: 969
# Iter # 10
# Winner thresh: 0.999
# Ensemble score: 0.970146750524
# Transferred unlabeled observations: 9
# Transfer distribution: [9, 0]
# Cumulative transfer: 978
# Iter # 11
# Winner thresh: 0.999
# Ensemble score: 0.970398322851
# Transferred unlabeled observations: 19
# Transfer distribution: [19, 0]
# Cumulative transfer: 997
# Iter # 12
# Winner thresh: 0.999
# Ensemble score: 0.971153039832
# Transferred unlabeled observations: 16
# Transfer distribution: [16, 0]
# Cumulative transfer: 1013
# Iter # 13
# Winner thresh: 0.999
# Ensemble score: 0.971991614256
# Transferred unlabeled observations: 9
# Transfer distribution: [9, 0]
# Cumulative transfer: 1022
# Iter # 14
# Winner thresh: 0.999
# Ensemble score: 0.970230607966
# Transferred unlabeled observations: 9
# Transfer distribution: [9, 0]
# Cumulative transfer: 1031
# Iter # 15
# Winner thresh: 0.999
# Ensemble score: 0.970817610063
# Transferred unlabeled observations: 13
# Transfer distribution: [13, 0]
# Cumulative transfer: 1044
# Iter # 16
# Winner thresh: 0.999
# Ensemble score: 0.969979035639
# Transferred unlabeled observations: 11
# Transfer distribution: [11, 0]
# Cumulative transfer: 1055
# Iter # 17
# Winner thresh: 0.999
# Ensemble score: 0.971404612159
# Transferred unlabeled observations: 14
# Transfer distribution: [14, 0]
# Cumulative transfer: 1069
# Iter # 18
# Winner thresh: 0.999
# Ensemble score: 0.970817610063
# Transferred unlabeled observations: 5
# Transfer distribution: [5, 0]
# Cumulative transfer: 1074
# Iter # 19
# Winner thresh: 0.999
# Ensemble score: 0.971991614256
# Transferred unlabeled observations: 9
# Transfer distribution: [9, 0]
# Cumulative transfer: 1083
# Iter # 20
# Winner thresh: 0.999
# Ensemble score: 0.97106918239
# Transferred unlabeled observations: 7
# Transfer distribution: [7, 0]
# Cumulative transfer: 1090
# Iter # 21
# Winner thresh: 0.999
# Ensemble score: 0.970649895178
# Transferred unlabeled observations: 4
# Transfer distribution: [4, 0]
# Cumulative transfer: 1094
# Iter # 22
# Winner thresh: 0.999
# Ensemble score: 0.970649895178
# Transferred unlabeled observations: 5
# Transfer distribution: [5, 0]
# Cumulative transfer: 1099
# Iter # 23
# Winner thresh: 0.999
# Ensemble score: 0.971823899371
# Transferred unlabeled observations: 8
# Transfer distribution: [8, 0]
# Cumulative transfer: 1107
# Iter # 24
# Winner thresh: 0.999
# Ensemble score: 0.971572327044
# Transferred unlabeled observations: 7
# Transfer distribution: [7, 0]
# Cumulative transfer: 1114
# Iter # 25
# Winner thresh: 0.999
# Ensemble score: 0.970146750524
# Transferred unlabeled observations: 7
# Transfer distribution: [7, 0]
# Cumulative transfer: 1121
# Iter # 26
# Winner thresh: 0.999
# Ensemble score: 0.971320754717
# Transferred unlabeled observations: 1
# Transfer distribution: [1, 0]
# Cumulative transfer: 1122
# Iter # 27
# Winner thresh: 0.999
# Ensemble score: 0.968888888889
# Transferred unlabeled observations: 3
# Transfer distribution: [3, 0]
# Cumulative transfer: 1125
# Iter # 28
# Winner thresh: 0.999
# Ensemble score: 0.972997903564
# Transferred unlabeled observations: 4
# Transfer distribution: [4, 0]
# Cumulative transfer: 1129
# Iter # 29
# Winner thresh: 0.999
# Ensemble score: 0.969308176101
# Transferred unlabeled observations: 1
# Transfer distribution: [1, 0]
# Cumulative transfer: 1130
# Iter # 30
# Winner thresh: 0.999
# Ensemble score: 0.971320754717
# Transferred unlabeled observations: 1
# Transfer distribution: [1, 0]
# Cumulative transfer: 1131
# Iter # 31
# Winner thresh: 0.999
# Ensemble score: 0.969475890985
# Transferred unlabeled observations: 2
# Transfer distribution: [2, 0]
# Cumulative transfer: 1133
# Iter # 32
# Winner thresh: 0.999
# Ensemble score: 0.970733752621
# Transferred unlabeled observations: 6
# Transfer distribution: [6, 0]
# Cumulative transfer: 1139
# Iter # 33
# Winner thresh: 0.999
# Ensemble score: 0.968972746331
# Transferred unlabeled observations: 3
# Transfer distribution: [3, 0]
# Cumulative transfer: 1142
# Iter # 34
# Winner thresh: 0.999
# Ensemble score: 0.970817610063
# Transferred unlabeled observations: 2
# Transfer distribution: [2, 0]
# Cumulative transfer: 1144
# Iter # 35
# Winner thresh: 0.999
# Ensemble score: 0.97106918239
# Transferred unlabeled observations: 3
# Transfer distribution: [3, 0]
# Cumulative transfer: 1147
# Iter # 36
# Winner thresh: 0.999
# Ensemble score: 0.971740041929
# Transferred unlabeled observations: 2
# Transfer distribution: [2, 0]
# Cumulative transfer: 1149
# Iter # 37
# Winner thresh: 0.999
# Ensemble score: 0.970733752621
# Transferred unlabeled observations: 5
# Transfer distribution: [5, 0]
# Cumulative transfer: 1154
# Iter # 38
# Winner thresh: 0.999
# Ensemble score: 0.971823899371
# Transferred unlabeled observations: 4
# Transfer distribution: [4, 0]
# Cumulative transfer: 1158
# Iter # 39
# Winner thresh: 0.999
# Ensemble score: 0.970566037736
# Transferred unlabeled observations: 6
# Transfer distribution: [6, 0]
# Cumulative transfer: 1164
# Iter # 40
# Winner thresh: 0.999
# Ensemble score: 0.971907756813
# Transferred unlabeled observations: 3
# Transfer distribution: [3, 0]
# Cumulative transfer: 1167
# Iter # 41
# Winner thresh: 0.999
# Ensemble score: 0.971907756813
# Transferred unlabeled observations: 3
# Transfer distribution: [3, 0]
# Cumulative transfer: 1170
# Iter # 42
# Winner thresh: 0.999
# Ensemble score: 0.970985324948
# Transferred unlabeled observations: 1
# Transfer distribution: [1, 0]
# Cumulative transfer: 1171
# Iter # 43
# Winner thresh: 0.999
# Ensemble score: 0.970062893082
# Transferred unlabeled observations: 25
# Transfer distribution: [25, 0]
# Cumulative transfer: 1196
# Iter # 44
# Winner thresh: 0.999
# Ensemble score: 0.971740041929
# Transferred unlabeled observations: 53
# Transfer distribution: [53, 0]
# Cumulative transfer: 1249
# Iter # 45
# Winner thresh: 0.999
# Ensemble score: 0.971991614256
# Transferred unlabeled observations: 141
# Transfer distribution: [141, 0]
# Cumulative transfer: 1390
# Iter # 46
# Winner thresh: 0.999
# Ensemble score: 0.971320754717
# Transferred unlabeled observations: 484
# Transfer distribution: [484, 0]
# Cumulative transfer: 1874
# Iter # 47
# Winner thresh: 0.999
# Ensemble score: 0.970901467505
# Transferred unlabeled observations: 1
# Transfer distribution: [1, 0]
# Cumulative transfer: 1875
# Iter # 48
# Winner thresh: 0.999
# Ensemble score: 0.971572327044
# Transferred unlabeled observations: 2
# Transfer distribution: [2, 0]
# Cumulative transfer: 1877
# Iter # 49
# Winner thresh: 0.999
# Ensemble score: 0.971572327044
# Transferred unlabeled observations: 3
# Transfer distribution: [3, 0]
# Cumulative transfer: 1880
# Iter # 50
# Winner thresh: 0.999
# Ensemble score: 0.970901467505
# Transferred unlabeled observations: 4
# Transfer distribution: [4, 0]
# Cumulative transfer: 1884
# Iter # 51
# Winner thresh: 0.999
# Ensemble score: 0.96964360587
# Transferred unlabeled observations: 2
# Transfer distribution: [2, 0]
# Cumulative transfer: 1886
# Iter # 52
# Winner thresh: 0.999
# Ensemble score: 0.971236897275
# Transferred unlabeled observations: 3
# Transfer distribution: [3, 0]
# Cumulative transfer: 1889
# Iter # 53
# Winner thresh: 0.999
# Ensemble score: 0.970985324948
# Transferred unlabeled observations: 7
# Transfer distribution: [7, 0]
# Cumulative transfer: 1896
# Iter # 54
# Winner thresh: 0.999
# Ensemble score: 0.969811320755
# Transferred unlabeled observations: 1
# Transfer distribution: [1, 0]
# Cumulative transfer: 1897
# Iter # 55
# Winner thresh: 0.999
# Ensemble score: 0.97106918239
# Transferred unlabeled observations: 2
# Transfer distribution: [2, 0]
# Cumulative transfer: 1899
# Iter # 56
# Winner thresh: 0.999
# Ensemble score: 0.970062893082
# Transferred unlabeled observations: 0
# Transfer distribution: [0, 0]
# Cumulative transfer: 1899
# Iter # 57
# Winner thresh: 0.998001
# Ensemble score: 0.971907756813
# Transferred unlabeled observations: 6
# Transfer distribution: [6, 0]
# Cumulative transfer: 1905
# Iter # 58
# Winner thresh: 0.998001
# Ensemble score: 0.970566037736
# Transferred unlabeled observations: 18
# Transfer distribution: [18, 0]
# Cumulative transfer: 1923
# Iter # 59
# Winner thresh: 0.998001
# Ensemble score: 0.970985324948
# Transferred unlabeled observations: 15
# Transfer distribution: [15, 0]
# Cumulative transfer: 1938
# Iter # 60
# Winner thresh: 0.998001
# Ensemble score: 0.973165618449
# Transferred unlabeled observations: 764
# Transfer distribution: [764, 0]
# Cumulative transfer: 2702
# Iter # 61
# Winner thresh: 0.998001
# Ensemble score: 0.971488469602
# Transferred unlabeled observations: 13
# Transfer distribution: [13, 0]
# Cumulative transfer: 2715
# Iter # 62
# Winner thresh: 0.998001
# Ensemble score: 0.972243186583
# Transferred unlabeled observations: 13
# Transfer distribution: [13, 0]
# Cumulative transfer: 2728
# Iter # 63
# Winner thresh: 0.998001
# Ensemble score: 0.970985324948
# Transferred unlabeled observations: 7
# Transfer distribution: [7, 0]
# Cumulative transfer: 2735
# Iter # 64
# Winner thresh: 0.998001
# Ensemble score: 0.971236897275
# Transferred unlabeled observations: 4
# Transfer distribution: [4, 0]
# Cumulative transfer: 2739
# Iter # 65
# Winner thresh: 0.998001
# Ensemble score: 0.970817610063
# Transferred unlabeled observations: 12
# Transfer distribution: [12, 0]
# Cumulative transfer: 2751
# Iter # 66
# Winner thresh: 0.998001
# Ensemble score: 0.971740041929
# Transferred unlabeled observations: 5
# Transfer distribution: [5, 0]
# Cumulative transfer: 2756
# Iter # 67
# Winner thresh: 0.998001
# Ensemble score: 0.97106918239
# Transferred unlabeled observations: 9
# Transfer distribution: [9, 0]
# Cumulative transfer: 2765
# Iter # 68
# Winner thresh: 0.998001
# Ensemble score: 0.971656184486
# Transferred unlabeled observations: 4
# Transfer distribution: [4, 0]
# Cumulative transfer: 2769
# Iter # 69
# Winner thresh: 0.998001
# Ensemble score: 0.970985324948
# Transferred unlabeled observations: 9
# Transfer distribution: [9, 0]
# Cumulative transfer: 2778
# Iter # 70
# Winner thresh: 0.998001
# Ensemble score: 0.96964360587
# Transferred unlabeled observations: 5
# Transfer distribution: [5, 0]
# Cumulative transfer: 2783
# Iter # 71
# Winner thresh: 0.998001
# Ensemble score: 0.969727463312
# Transferred unlabeled observations: 7
# Transfer distribution: [7, 0]
# Cumulative transfer: 2790
# Iter # 72
# Winner thresh: 0.998001
# Ensemble score: 0.970649895178
# Transferred unlabeled observations: 4
# Transfer distribution: [4, 0]
# Cumulative transfer: 2794
# Iter # 73
# Winner thresh: 0.998001
# Ensemble score: 0.970062893082
# Transferred unlabeled observations: 9
# Transfer distribution: [9, 0]
# Cumulative transfer: 2803
# Iter # 74
# Winner thresh: 0.998001
# Ensemble score: 0.971153039832
# Transferred unlabeled observations: 9
# Transfer distribution: [9, 0]
# Cumulative transfer: 2812
# Iter # 75
# Winner thresh: 0.998001
# Ensemble score: 0.970230607966
# Transferred unlabeled observations: 3
# Transfer distribution: [3, 0]
# Cumulative transfer: 2815
# Iter # 76
# Winner thresh: 0.998001
# Ensemble score: 0.971488469602
# Transferred unlabeled observations: 5
# Transfer distribution: [5, 0]
# Cumulative transfer: 2820
# Iter # 77
# Winner thresh: 0.998001
# Ensemble score: 0.969559748428
# Transferred unlabeled observations: 6
# Transfer distribution: [6, 0]
# Cumulative transfer: 2826
# Iter # 78
# Winner thresh: 0.998001
# Ensemble score: 0.971488469602
# Transferred unlabeled observations: 3
# Transfer distribution: [3, 0]
# Cumulative transfer: 2829
# Iter # 79
# Winner thresh: 0.998001
# Ensemble score: 0.971404612159
# Transferred unlabeled observations: 3
# Transfer distribution: [3, 0]
# Cumulative transfer: 2832
# Iter # 80
# Winner thresh: 0.998001
# Ensemble score: 0.971907756813
# Transferred unlabeled observations: 5
# Transfer distribution: [5, 0]
# Cumulative transfer: 2837
# Iter # 81
# Winner thresh: 0.998001
# Ensemble score: 0.971656184486
# Transferred unlabeled observations: 6
# Transfer distribution: [6, 0]
# Cumulative transfer: 2843
# Iter # 82
# Winner thresh: 0.998001
# Ensemble score: 0.971153039832
# Transferred unlabeled observations: 2
# Transfer distribution: [2, 0]
# Cumulative transfer: 2845
# Iter # 83
# Winner thresh: 0.998001
# Ensemble score: 0.970901467505
# Transferred unlabeled observations: 3
# Transfer distribution: [3, 0]
# Cumulative transfer: 2848
# Iter # 84
# Winner thresh: 0.998001
# Ensemble score: 0.970398322851
# Transferred unlabeled observations: 1
# Transfer distribution: [1, 0]
# Cumulative transfer: 2849
# Iter # 85
# Winner thresh: 0.998001
# Ensemble score: 0.971320754717
# Transferred unlabeled observations: 1
# Transfer distribution: [1, 0]
# Cumulative transfer: 2850
# Iter # 86
# Winner thresh: 0.998001
# Ensemble score: 0.970230607966
# Transferred unlabeled observations: 8
# Transfer distribution: [8, 0]
# Cumulative transfer: 2858
# Iter # 87
# Winner thresh: 0.998001
# Ensemble score: 0.971656184486
# Transferred unlabeled observations: 1
# Transfer distribution: [1, 0]
# Cumulative transfer: 2859
# Iter # 88
# Winner thresh: 0.998001
# Ensemble score: 0.970566037736
# Transferred unlabeled observations: 3
# Transfer distribution: [3, 0]
# Cumulative transfer: 2862
# Iter # 89
# Winner thresh: 0.998001
# Ensemble score: 0.970733752621
# Transferred unlabeled observations: 3
# Transfer distribution: [3, 0]
# Cumulative transfer: 2865
# Iter # 90
# Winner thresh: 0.998001
# Ensemble score: 0.970817610063
# Transferred unlabeled observations: 3
# Transfer distribution: [3, 0]
# Cumulative transfer: 2868
# Iter # 91
# Winner thresh: 0.998001
# Ensemble score: 0.969811320755
# Transferred unlabeled observations: 4
# Transfer distribution: [4, 0]
# Cumulative transfer: 2872
# Iter # 92
# Winner thresh: 0.998001
# Ensemble score: 0.97215932914
# Transferred unlabeled observations: 1
# Transfer distribution: [1, 0]
# Cumulative transfer: 2873
# Iter # 93
# Winner thresh: 0.998001
# Ensemble score: 0.970817610063
# Transferred unlabeled observations: 4
# Transfer distribution: [4, 0]
# Cumulative transfer: 2877
# Iter # 94
# Winner thresh: 0.998001
# Ensemble score: 0.971823899371
# Transferred unlabeled observations: 5
# Transfer distribution: [5, 0]
# Cumulative transfer: 2882
# Iter # 95
# Winner thresh: 0.998001
# Ensemble score: 0.970566037736
# Transferred unlabeled observations: 4
# Transfer distribution: [4, 0]
# Cumulative transfer: 2886
# Iter # 96
# Winner thresh: 0.998001
# Ensemble score: 0.973165618449
# Transferred unlabeled observations: 2
# Transfer distribution: [2, 0]
# Cumulative transfer: 2888
# Iter # 97
# Winner thresh: 0.998001
# Ensemble score: 0.971740041929
# Transferred unlabeled observations: 4
# Transfer distribution: [4, 0]
# Cumulative transfer: 2892
# Iter # 98
# Winner thresh: 0.998001
# Ensemble score: 0.970817610063
# Transferred unlabeled observations: 3
# Transfer distribution: [3, 0]
# Cumulative transfer: 2895
# Iter # 99
# Winner thresh: 0.998001
# Ensemble score: 0.971991614256
# Transferred unlabeled observations: 2
# Transfer distribution: [2, 0]
# Cumulative transfer: 2897
# Iter # 100
# Winner thresh: 0.998001
# Ensemble score: 0.971488469602
# Transferred unlabeled observations: 2
# Transfer distribution: [2, 0]
# Cumulative transfer: 2899
# Iter # 101
# Winner thresh: 0.998001
# Ensemble score: 0.970398322851
# Transferred unlabeled observations: 0
# Transfer distribution: [0, 0]
# Cumulative transfer: 2899
# Iter # 102
# Winner thresh: 0.996005996001
# Ensemble score: 0.970817610063
# Transferred unlabeled observations: 9
# Transfer distribution: [9, 0]
# Cumulative transfer: 2908
# Iter # 103
# Winner thresh: 0.996005996001
# Ensemble score: 0.970062893082
# Transferred unlabeled observations: 78
# Transfer distribution: [78, 0]
# Cumulative transfer: 2986
# Iter # 104
# Winner thresh: 0.996005996001
# Ensemble score: 0.971320754717
# Transferred unlabeled observations: 8
# Transfer distribution: [8, 0]
# Cumulative transfer: 2994
# Iter # 105
# Winner thresh: 0.996005996001
# Ensemble score: 0.972578616352
# Transferred unlabeled observations: 9
# Transfer distribution: [9, 0]
# Cumulative transfer: 3003
# Iter # 106
# Winner thresh: 0.996005996001
# Ensemble score: 0.972410901468
# Transferred unlabeled observations: 7
# Transfer distribution: [7, 0]
# Cumulative transfer: 3010
# Iter # 107
# Winner thresh: 0.996005996001
# Ensemble score: 0.970482180294
# Transferred unlabeled observations: 8
# Transfer distribution: [8, 0]
# Cumulative transfer: 3018
# Iter # 108
# Winner thresh: 0.996005996001
# Ensemble score: 0.972075471698
# Transferred unlabeled observations: 11
# Transfer distribution: [11, 0]
# Cumulative transfer: 3029
# Iter # 109
# Winner thresh: 0.996005996001
# Ensemble score: 0.970398322851
# Transferred unlabeled observations: 12
# Transfer distribution: [12, 0]
# Cumulative transfer: 3041
# Iter # 110
# Winner thresh: 0.996005996001
# Ensemble score: 0.97215932914
# Transferred unlabeled observations: 6
# Transfer distribution: [6, 0]
# Cumulative transfer: 3047
# Iter # 111
# Winner thresh: 0.996005996001
# Ensemble score: 0.972578616352
# Transferred unlabeled observations: 5
# Transfer distribution: [5, 0]
# Cumulative transfer: 3052
# Iter # 112
# Winner thresh: 0.996005996001
# Ensemble score: 0.972075471698
# Transferred unlabeled observations: 5
# Transfer distribution: [5, 0]
# Cumulative transfer: 3057
# Iter # 113
# Winner thresh: 0.996005996001
# Ensemble score: 0.970482180294
# Transferred unlabeled observations: 3
# Transfer distribution: [3, 0]
# Cumulative transfer: 3060
# Iter # 114
# Winner thresh: 0.996005996001
# Ensemble score: 0.97249475891
# Transferred unlabeled observations: 2
# Transfer distribution: [2, 0]
# Cumulative transfer: 3062
# Iter # 115
# Winner thresh: 0.996005996001
# Ensemble score: 0.969727463312
# Transferred unlabeled observations: 1
# Transfer distribution: [1, 0]
# Cumulative transfer: 3063
# Iter # 116
# Winner thresh: 0.996005996001
# Ensemble score: 0.971656184486
# Transferred unlabeled observations: 3
# Transfer distribution: [3, 0]
# Cumulative transfer: 3066
# Iter # 117
# Winner thresh: 0.996005996001
# Ensemble score: 0.971991614256
# Transferred unlabeled observations: 7
# Transfer distribution: [7, 0]
# Cumulative transfer: 3073
# Iter # 118
# Winner thresh: 0.996005996001
# Ensemble score: 0.970062893082
# Transferred unlabeled observations: 1
# Transfer distribution: [1, 0]
# Cumulative transfer: 3074
# Iter # 119
# Winner thresh: 0.996005996001
# Ensemble score: 0.970733752621
# Transferred unlabeled observations: 3
# Transfer distribution: [3, 0]
# Cumulative transfer: 3077
# Iter # 120
# Winner thresh: 0.996005996001
# Ensemble score: 0.970649895178
# Transferred unlabeled observations: 5
# Transfer distribution: [5, 0]
# Cumulative transfer: 3082
# Iter # 121
# Winner thresh: 0.996005996001
# Ensemble score: 0.970733752621
# Transferred unlabeled observations: 1
# Transfer distribution: [1, 0]
# Cumulative transfer: 3083
# Iter # 122
# Winner thresh: 0.996005996001
# Ensemble score: 0.97106918239
# Transferred unlabeled observations: 2
# Transfer distribution: [2, 0]
# Cumulative transfer: 3085
# Iter # 123
# Winner thresh: 0.996005996001
# Ensemble score: 0.97215932914
# Transferred unlabeled observations: 1
# Transfer distribution: [1, 0]
# Cumulative transfer: 3086
# Iter # 124
# Winner thresh: 0.996005996001
# Ensemble score: 0.970314465409
# Transferred unlabeled observations: 1
# Transfer distribution: [1, 0]
# Cumulative transfer: 3087
# Iter # 125
# Winner thresh: 0.996005996001
# Ensemble score: 0.970985324948
# Transferred unlabeled observations: 7
# Transfer distribution: [7, 0]
# Cumulative transfer: 3094
# Iter # 126
# Winner thresh: 0.996005996001
# Ensemble score: 0.969727463312
# Transferred unlabeled observations: 0
# Transfer distribution: [0, 0]
# Cumulative transfer: 3094
# Iter # 127
# Winner thresh: 0.99202794407
# Ensemble score: 0.972830188679
# Transferred unlabeled observations: 25
# Transfer distribution: [25, 0]
# Cumulative transfer: 3119
# Iter # 128
# Winner thresh: 0.99202794407
# Ensemble score: 0.971740041929
# Transferred unlabeled observations: 30
# Transfer distribution: [30, 0]
# Cumulative transfer: 3149
# Iter # 129
# Winner thresh: 0.99202794407
# Ensemble score: 0.970649895178
# Transferred unlabeled observations: 31
# Transfer distribution: [31, 0]
# Cumulative transfer: 3180
# Iter # 130
# Winner thresh: 0.99202794407
# Ensemble score: 0.972662473795
# Transferred unlabeled observations: 12
# Transfer distribution: [12, 0]
# Cumulative transfer: 3192
# Iter # 131
# Winner thresh: 0.99202794407
# Ensemble score: 0.971823899371
# Transferred unlabeled observations: 15
# Transfer distribution: [15, 0]
# Cumulative transfer: 3207
# Iter # 132
# Winner thresh: 0.99202794407
# Ensemble score: 0.97215932914
# Transferred unlabeled observations: 15
# Transfer distribution: [15, 0]
# Cumulative transfer: 3222
# Iter # 133
# Winner thresh: 0.99202794407
# Ensemble score: 0.972662473795
# Transferred unlabeled observations: 8
# Transfer distribution: [8, 0]
# Cumulative transfer: 3230
# Iter # 134
# Winner thresh: 0.99202794407
# Ensemble score: 0.971823899371
# Transferred unlabeled observations: 9
# Transfer distribution: [9, 0]
# Cumulative transfer: 3239
# Iter # 135
# Winner thresh: 0.99202794407
# Ensemble score: 0.971153039832
# Transferred unlabeled observations: 8
# Transfer distribution: [8, 0]
# Cumulative transfer: 3247
# Iter # 136
# Winner thresh: 0.99202794407
# Ensemble score: 0.971823899371
# Transferred unlabeled observations: 5
# Transfer distribution: [5, 0]
# Cumulative transfer: 3252
# Iter # 137
# Winner thresh: 0.99202794407
# Ensemble score: 0.971991614256
# Transferred unlabeled observations: 5
# Transfer distribution: [5, 0]
# Cumulative transfer: 3257
# Iter # 138
# Winner thresh: 0.99202794407
# Ensemble score: 0.971572327044
# Transferred unlabeled observations: 2
# Transfer distribution: [2, 0]
# Cumulative transfer: 3259
# Iter # 139
# Winner thresh: 0.99202794407
# Ensemble score: 0.971991614256
# Transferred unlabeled observations: 8
# Transfer distribution: [8, 0]
# Cumulative transfer: 3267
# Iter # 140
# Winner thresh: 0.99202794407
# Ensemble score: 0.972746331237
# Transferred unlabeled observations: 4
# Transfer distribution: [4, 0]
# Cumulative transfer: 3271
# Iter # 141
# Winner thresh: 0.99202794407
# Ensemble score: 0.972914046122
# Transferred unlabeled observations: 4
# Transfer distribution: [4, 0]
# Cumulative transfer: 3275
# Iter # 142
# Winner thresh: 0.99202794407
# Ensemble score: 0.971153039832
# Transferred unlabeled observations: 1
# Transfer distribution: [1, 0]
# Cumulative transfer: 3276
# Iter # 143
# Winner thresh: 0.99202794407
# Ensemble score: 0.971740041929
# Transferred unlabeled observations: 3
# Transfer distribution: [3, 0]
# Cumulative transfer: 3279
# Iter # 144
# Winner thresh: 0.99202794407
# Ensemble score: 0.972578616352
# Transferred unlabeled observations: 2
# Transfer distribution: [2, 0]
# Cumulative transfer: 3281
# Iter # 145
# Winner thresh: 0.99202794407
# Ensemble score: 0.971572327044
# Transferred unlabeled observations: 6
# Transfer distribution: [6, 0]
# Cumulative transfer: 3287
# Iter # 146
# Winner thresh: 0.99202794407
# Ensemble score: 0.970398322851
# Transferred unlabeled observations: 1
# Transfer distribution: [1, 0]
# Cumulative transfer: 3288
# Iter # 147
# Winner thresh: 0.99202794407
# Ensemble score: 0.971907756813
# Transferred unlabeled observations: 3
# Transfer distribution: [3, 0]
# Cumulative transfer: 3291
# Iter # 148
# Winner thresh: 0.99202794407
# Ensemble score: 0.972327044025
# Transferred unlabeled observations: 1
# Transfer distribution: [1, 0]
# Cumulative transfer: 3292
# Iter # 149
# Winner thresh: 0.99202794407
# Ensemble score: 0.970230607966
# Transferred unlabeled observations: 2
# Transfer distribution: [2, 0]
# Cumulative transfer: 3294
# Iter # 150
# Winner thresh: 0.99202794407
# Ensemble score: 0.972075471698
# Transferred unlabeled observations: 0
# Transfer distribution: [0, 0]
# Cumulative transfer: 3294
# Iter # 151
# Winner thresh: 0.984119441816
# Ensemble score: 0.972662473795
# Transferred unlabeled observations: 36
# Transfer distribution: [36, 0]
# Cumulative transfer: 3330
# Iter # 152
# Winner thresh: 0.984119441816
# Ensemble score: 0.973249475891
# Transferred unlabeled observations: 27
# Transfer distribution: [27, 0]
# Cumulative transfer: 3357
# Iter # 153
# Winner thresh: 0.984119441816
# Ensemble score: 0.971907756813
# Transferred unlabeled observations: 18
# Transfer distribution: [18, 0]
# Cumulative transfer: 3375
# Iter # 154
# Winner thresh: 0.984119441816
# Ensemble score: 0.972075471698
# Transferred unlabeled observations: 16
# Transfer distribution: [16, 0]
# Cumulative transfer: 3391
# Iter # 155
# Winner thresh: 0.984119441816
# Ensemble score: 0.971572327044
# Transferred unlabeled observations: 16
# Transfer distribution: [16, 0]
# Cumulative transfer: 3407
# Iter # 156
# Winner thresh: 0.984119441816
# Ensemble score: 0.970901467505
# Transferred unlabeled observations: 10
# Transfer distribution: [10, 0]
# Cumulative transfer: 3417
# Iter # 157
# Winner thresh: 0.984119441816
# Ensemble score: 0.971572327044
# Transferred unlabeled observations: 4
# Transfer distribution: [4, 0]
# Cumulative transfer: 3421
# Iter # 158
# Winner thresh: 0.984119441816
# Ensemble score: 0.972327044025
# Transferred unlabeled observations: 6
# Transfer distribution: [6, 0]
# Cumulative transfer: 3427
# Iter # 159
# Winner thresh: 0.984119441816
# Ensemble score: 0.969811320755
# Transferred unlabeled observations: 6
# Transfer distribution: [6, 0]
# Cumulative transfer: 3433

# %%
len(models)
# Out:
# 32

# %%
q = models[0]
q.n_features_
# Out:
# 37

# %%
plt.figure(figsize=(20,10))
sns.set_style("darkgrid")

def movingaverage(interval, window_size):
    window= np.ones(int(window_size))/float(window_size)
    return np.convolve(interval, window, 'same')


# plt.plot(score_list)
ws = 20
# sns.tsplot(movingaverage(score_list, ws)[ws/2:-ws/2])
sns.tsplot(score_list)

# %%
np.unique(np.array(sub_sps).flatten()).shape
# Out:
# (74,)

# %% [markdown]
# #PREDICTION

# %%
sub = pd.read_csv('../data/sampleSubmission.csv')

# %%
y_pred_list = []
for s_i, sub_sp in enumerate(sub_sps):
    X_test_sub = X_test[:, sub_sp]
    model = models[s_i]
    y_pred_list.append(model.predict_proba(X_test_sub)[:, 1])

y_pred_avg = np.array(y_pred_list).mean(axis=0)

# %%
sub['prediction'] = y_pred_avg
sub.to_csv('../submissions/rasco160-et128_id-boxcox.csv', index=False)

# %%
plt.figure(figsize=(20,10))
# plt.plot(np.array(y_pred_list).T, alpha=0.8);
plt.plot(y_pred_avg, lw=0.5, c='black');

# %%
plt.figure(figsize=(20,10))
y_pred_sum = np.array(y_pred_list).sum(axis=0)
plt.hist(y_pred_sum)
# Out:
# (array([ 3738.,   386.,   238.,   116.,    78.,    38.,    27.,    32.,
#            35.,    12.]),
#  array([  0.        ,   7.28499168,  14.56998336,  21.85497504,
#          29.13996672,  36.4249584 ,  43.70995008,  50.99494177,
#          58.27993345,  65.56492513,  72.84991681]),
#  <a list of 10 Patch objects>)
