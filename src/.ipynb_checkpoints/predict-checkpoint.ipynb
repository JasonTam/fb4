# %%
import sys
sys.path.append('../')

import pandas as pd
import os                                                                                               
from src import data_io
import shelve
from contextlib import closing
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cPickle as pickle

from sklearn.svm import SVC, LinearSVC
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
from sklearn.cross_validation import StratifiedKFold
from sklearn.cross_validation import cross_val_score

from sklearn.decomposition import PCA, TruncatedSVD

from time import time

# %%
load = True
if load:
    bidders_d, auctions_d = data_io.load_bidders_auctions()
    
train_ids = [bidder_id for bidder_id, bidder in bidders_d.items() 
             if bidder.true_outcome != None]

train_bidders = [bidders_d[train_id] for train_id in train_ids]

# %%
bids_df = data_io.load_bids()

# %%
y = np.array([b.true_outcome for b in train_bidders])
k = 4
skf = StratifiedKFold(y, n_folds=k, random_state=0)

# %%
snipe_feats = pickle.load((open('../data/snipe_counts.p', 'rb')))
diversity_feats = pd.read_pickle('../data/df_diversity_feats.p').to_dict()['diversity_feat']
peak_feats = pd.read_pickle('../data/df_peak_feats.p').to_dict()['peak_feat']
peak_feats5e9 = pd.read_pickle('../data/df_peak5e9_feats.p').to_dict()['peak_feat']
peak_feats2e10 = pd.read_pickle('../data/df_peak2e10_feats.p').to_dict()['peak_feat']
peak_feats1e11 = pd.read_pickle('../data/df_peak1e11_feats.p').to_dict()['peak_feat']
count_feats = pd.read_pickle('../data/df_counts_feats.p').to_dict()['counts_feat']

# %%
import features
reload(features)
from features import *

tic = time()

X1 = [snipe_feats[b.bidder_id] for b in train_bidders]
X2 = BidsPerAuct().transform(train_bidders)
# X3 = BidDiversity(bids_df).transform(train_bidders)
X3 = [diversity_feats[b.bidder_id] for b in train_bidders]
X4 = [count_feats[b.bidder_id] for b in train_bidders]

X5_1 = [peak_feats[b.bidder_id] for b in train_bidders]
X5_2 = [peak_feats5e9[b.bidder_id] for b in train_bidders]
X5_3 = [peak_feats2e10[b.bidder_id] for b in train_bidders]
X5_4 = [peak_feats1e11[b.bidder_id] for b in train_bidders]

# X = np.c_[X1, X2, X3]
# X = np.c_[X2, X3, X4]
X = np.c_[X2, X3, np.array(X4)[:, keep_inds],
         X5_1, X5_2, X5_3, X5_4]
# X = np.c_[X2, X3, X4, PCA(n_components=5).fit_transform(np.array(X5)[:, keep_inds])]

# X = np.c_[X1, X2, X3, X4, X5]

print X.shape
# Out:
# (2013, 60)

# %%
np.save('../data/X.npy', X)

# %% [markdown]
# # Visualization?

# %%
import bhtsne

# tsne2 = bhtsne.bh_tsne(X, no_dims=2)
# tsne3 = bhtsne.bh_tsne(X, no_dims=3)
X2_all = BidsPerAuct().transform(bidders_d.values())
X3_all = [diversity_feats[b] for b in bidders_d.keys()]
X4_all = np.sqrt(np.array([count_feats[b] for b in bidders_d.keys()]) + 3/8.)

X5_1_all = [peak_feats[b] for b in bidders_d.keys()]
X5_2_all = [peak_feats5e9[b] for b in bidders_d.keys()]
X5_3_all = [peak_feats2e10[b] for b in bidders_d.keys()]
X5_4_all = [peak_feats1e11[b] for b in bidders_d.keys()]

# X_all = np.c_[X2_all, X3_all, X4_all, X5_all]
# X_all = np.c_[X5_all]
# X_all = np.array(X5_all)[:, keep_inds]
X_all = np.c_[X2_all, X3_all, np.array(X4_all)[:, keep_inds],
             X5_1_all, X5_2_all, X5_3_all, X5_4_all]

tsne2 = bhtsne.bh_tsne(X_all, no_dims=2)
tsne3 = bhtsne.bh_tsne(X_all, no_dims=3)

X_tsne2 = np.array([result for result in tsne2])
# X_tsne3 = np.array([result for result in tsne3])

# %%
from sklearn.manifold import LocallyLinearEmbedding, Isomap, MDS, SpectralEmbedding

X2 = MDS().fit_transform(X_all)
# X2 = LocallyLinearEmbedding(eigen_solver='dense').fit_transform(X_all)
# X2 = Isomap(n_neighbors=20).fit_transform(X_all)
# X2 = SpectralEmbedding().fit_transform(X_all)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-303-3fa26c55442d> in <module>()
#       1 from sklearn.manifold import LocallyLinearEmbedding, Isomap, MDS, SpectralEmbedding
#       2
# ----> 3 X2 = MDS().fit_transform(X_all)
#       4 # X2 = LocallyLinearEmbedding(eigen_solver='dense').fit_transform(X_all)
#       5 # X2 = Isomap(n_neighbors=20).fit_transform(X_all)
#
# /afs/ee.cooper.edu/user/t/a/tam8/documents/scikit-learn/sklearn/manifold/mds.pyc in fit_transform(self, X, y, init)
#     410             n_jobs=self.n_jobs, max_iter=self.max_iter, verbose=self.verbose,
#     411             eps=self.eps, random_state=self.random_state,
# --> 412             return_n_iter=True)
#     413
#     414         return self.embedding_
#
# /afs/ee.cooper.edu/user/t/a/tam8/documents/scikit-learn/sklearn/manifold/mds.pyc in smacof(similarities, metric, n_components, init, n_init, n_jobs, max_iter, verbose, eps, random_state, return_n_iter)
#     247                 n_components=n_components, init=init,
#     248                 max_iter=max_iter, verbose=verbose,
# --> 249                 eps=eps, random_state=random_state)
#     250             if best_stress is None or stress < best_stress:
#     251                 best_stress = stress
#
# /afs/ee.cooper.edu/user/t/a/tam8/documents/scikit-learn/sklearn/manifold/mds.pyc in _smacof_single(similarities, metric, n_components, init, max_iter, verbose, eps, random_state)
#     107
#     108         # Compute stress
# --> 109         stress = ((dis.ravel() - disparities.ravel()) ** 2).sum() / 2
#     110
#     111         # Update X using the Guttman transform
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(20,10))
plt.scatter(X2[:,0], X2[:,1], c=y_tsne,
            lw=0.3, alpha=0.5,
            s=100)
plt.scatter(X2[np.where(y_tsne=='r'),0], X2[np.where(y_tsne=='r'),1],
            c='r', alpha=1, s=100)

# %%
# give y for test subjects
y_tsne = np.array([{0:'b', 1:'r', None:'gray'}[b.true_outcome] for b in bidders_d.values()])

# %%
plt.figure(figsize=(20,10))
# ec = {0: 'black', 1: 'r'}
# plt.scatter(X_tsne2[:,0], X_tsne2[:,1], c=y,
#             lw=1, alpha=1, 
#             cmap='Reds', edgecolor=[ec[y_i] for y_i in y],
#             s=100)

# ec = {0: 'black', 1: 'r'}
# plt.scatter(X_tsne2[np.where(y),0], X_tsne2[np.where(y),1],
#             lw=1, alpha=1, 
#             cmap='Reds', edgecolor=[ec[y_i] for y_i in y],
#             s=100)

plt.scatter(X_tsne2[:,0], X_tsne2[:,1], c=y_tsne,
            lw=0.3, alpha=0.5,
            s=100)
plt.scatter(X_tsne2[np.where(y_tsne=='r'),0], X_tsne2[np.where(y_tsne=='r'),1],
            c='r', alpha=1, s=100)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(20,10))
ax = Axes3D(fig)
ax.scatter(X_tsne3[:,0], X_tsne3[:,1], X_tsne3[:,2], c=y,
            lw=1, alpha=1, 
            cmap='Reds', edgecolor=[ec[y_i] for y_i in y],
            s=100)

# %%
# Adding tsne reduction to feats
X = np.c_[X, X_tsne3]

# %% [markdown]
# # Some sklearn models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline, make_union, Pipeline


# clf = LogisticRegression()
# clf = make_pipeline(StandardScaler(), SVC(probability=True))
# clf = AdaBoostClassifier(n_estimators=50, learning_rate=0.15)
# clf = BaggingClassifier(n_estimators=500,
#                         bootstrap_features=True,
#                         max_samples=1.0,
#                         max_features=0.9,
#                         n_jobs=-1)

clf = ExtraTreesClassifier(bootstrap=False, 
                           min_samples_leaf=3,
                           n_estimators=380,
                           min_samples_split=5,
                           criterion='entropy',
                           max_features=32,
                           max_depth=None,
                           n_jobs=-1,
                          )

# # for boxcox _ id feats
# clf = ExtraTreesClassifier(bootstrap=False, 
#                            min_samples_leaf=8,
#                            n_estimators=200,
#                            min_samples_split=7,
#                            criterion='entropy',
#                            max_features=30,
#                            max_depth=None,
#                            n_jobs=-1,
#                           )

# clf = AdaBoostClassifier(base_estimator=et, 
#                          n_estimators=10, 
#                          learning_rate=0.2)

# clf = make_pipeline(StandardScaler(),
#     KNeighborsClassifier(n_neighbors=100, weights='distance', metric='minkowski'))

# clf = GradientBoostingClassifier(n_estimators=1000)

# %%
## TRYING OUT RFE
clf.fit(X5, y)
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='entropy',
#            max_depth=None, max_features=32, max_leaf_nodes=None,
#            min_samples_leaf=3, min_samples_split=5,
#            min_weight_fraction_leaf=0.0, n_estimators=380, n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
plt.figure(figsize=(20,10))
fi = clf.feature_importances_
plt.scatter(range(len(fi)), fi, lw=0.1)
plt.xlim([0, 7900])
plt.ylim([0, 0.015])
# Out:
# (0, 0.015)

# %%
top_n = 5

keep_inds = (-fi).argsort()[:top_n]
keep_inds.shape
# Out:
# (5,)

# %%
import src.transformers
reload(src.transformers)
from src.transformers import *
from sklearn.preprocessing import MinMaxScaler

pipe = make_pipeline(make_union(
        IdentityTformer(), make_pipeline(AddTformer(1), BoxCoxTformer()),
#         IdentityTformer(),
#         AnscombeTformer(),
    ), clf)

# %%
from itertools import chain
scores_rep = []
for ii in range(5):
    print ii,
    scores = cross_val_score(
        estimator=pipe, 
        X=X, y=y, 
        scoring='roc_auc',
        cv=skf, 
        n_jobs=1)
    scores_rep.append(scores)
scores_all = np.array(list(chain(*scores_rep)))
# Out:
# 0 1 2 3 4

# %%
print scores_all
print scores_all.mean()
print scores_all.std()
# Out:
# [ 0.93031864  0.89547795  0.90461216  0.92293501  0.93619247  0.89463309
#   0.89747621  0.92062893  0.92895076  0.90143225  0.90638607  0.92574423
#   0.92557129  0.9051738   0.89098532  0.92419287  0.93739942  0.8993402
#   0.90820029  0.92331237]
# 0.913948166681
# 0.0146071489327

# %% [markdown]
# - 0.90901903543  nothing
# - 0.909414208061 log
# - 0.909018445702 tukey
# - 0.909177150196 InverseTformer
# - 0.909571835154 GLogTformer(1)
# - 0.913309346616 make_pipeline(AddTformer(1), BoxCoxTformer())

# %%
from sklearn.grid_search import RandomizedSearchCV
from scipy.stats import randint as sp_randint

param_dist = {
    "n_estimators": sp_randint(10, 500),
    "max_depth": [3, None],
    "max_features": sp_randint(1, X.shape[1]),
    "min_samples_split": sp_randint(1, 15),
    "min_samples_leaf": sp_randint(1, 15),
    "bootstrap": [True, False],
    "criterion": ["gini", "entropy"]}


n_iter_search = 500
random_search = RandomizedSearchCV(
    estimator=ExtraTreesClassifier(), 
    param_distributions=param_dist,
    scoring='roc_auc',
    cv=skf,
    n_iter=n_iter_search,
    n_jobs=-1)

tic = time()
random_search.fit(X, y)
toc = time() - tic
print toc
# Out:
# 1042.82421088

# %%
from scipy.stats import randint as sp_randint
param_dist = {
    "n_estimators": sp_randint(5, 500),
    "learning_rate": np.arange(0.1,1.5,0.05),}


n_iter_search = 500
random_search = RandomizedSearchCV(
    estimator=AdaBoostClassifier(), 
    param_distributions=param_dist,
    scoring='roc_auc',
    cv=skf,
    n_iter=n_iter_search,
    n_jobs=-1)

tic = time()
random_search.fit(X, y)
toc = time() - tic
print toc
# Out:
# 486.280086994

# %%
# PIPE

from sklearn.grid_search import RandomizedSearchCV
from scipy.stats import randint as sp_randint

pipe = Pipeline([('feats', make_union(
        IdentityTformer(), make_pipeline(AddTformer(1), BoxCoxTformer()),
    )), 
#                  ('etc', ExtraTreesClassifier()),
#                  ('ada', AdaBoostClassifier()),
                 ('bc', AdaBoostClassifier()),
                ])


# param_dist = {
#     "etc__n_estimators": sp_randint(10, 500),
#     "etc__max_depth": [3, None],
#     "etc__max_features": sp_randint(1, X.shape[1]),
#     "etc__min_samples_split": sp_randint(1, 15),
#     "etc__min_samples_leaf": sp_randint(1, 15),
#     "etc__bootstrap": [True, False],
#     "etc__criterion": ["gini", "entropy"]}

# param_dist = {
#     "ada__n_estimators": sp_randint(5, 500),
#     "ada__learning_rate": np.arange(0.1,1.5,0.05),}

param_dist = {
    "bc__n_estimators": 500,
    "bc__bootstrap_features": [False, Truebc__],
    "bc__max_samples": 1.0,
    "bc__max_features": 0.9,
}


n_iter_search = 100
random_search = RandomizedSearchCV(
    estimator=pipe, 
    param_distributions=param_dist,
    scoring='roc_auc',
    cv=skf,
    n_iter=n_iter_search,
    n_jobs=-1)

tic = time()
random_search.fit(X, y)
toc = time() - tic
print toc
# Out:
# 196.201013088

# %%
print random_search.best_score_
print random_search.best_params_
# Out:
# 0.904359721286
# {'ada__n_estimators': 48, 'ada__learning_rate': 0.15000000000000002}

# %% [markdown]
# #Trying XGBoost

# %%
import xgboost as xgb

# Parameters for XGB
params = {
    'num_class': 2,
    'silent': 0,    # 0 is verbose
    'nthread': 7,    # max if not set
    
    'bst:eta': .1,
    'bst:gamma': 0.5,
    'bst:max_depth': 500,
    'bst:min_child_weight': 10,
    'bst:max_delta_step': 8,
    'bst:subsample': .5,    # Row (observation) subsample
    'bst:colsample_bytree': 0.8,    # Col (feature) subsample
    
    'objective':'binary:logistic',
    'eval_metric': 'auc',
    
    'seed': 0,
}


dtrain = xgb.DMatrix(X, label=y)

# %%
num_round = 500
scores_xgb = xgb.cv(params, dtrain, num_round, nfold=4,
                    metrics={'auc'}, seed = 0)
# Out:
# [0]	cv-test-auc:0.556882+0.013898	cv-train-auc:0.512968+0.019292
# [1]	cv-test-auc:0.532553+0.040390	cv-train-auc:0.519440+0.028203
# [2]	cv-test-auc:0.557153+0.020518	cv-train-auc:0.546515+0.014796
# [3]	cv-test-auc:0.515425+0.039010	cv-train-auc:0.564891+0.039792
# [4]	cv-test-auc:0.547621+0.020638	cv-train-auc:0.570131+0.033087
# [5]	cv-test-auc:0.526450+0.010283	cv-train-auc:0.584273+0.039127
# [6]	cv-test-auc:0.520750+0.024748	cv-train-auc:0.620533+0.030745
# [7]	cv-test-auc:0.525409+0.015112	cv-train-auc:0.653774+0.017384
# [8]	cv-test-auc:0.515484+0.011827	cv-train-auc:0.661655+0.012836
# [9]	cv-test-auc:0.515712+0.019250	cv-train-auc:0.690835+0.019476
# [10]	cv-test-auc:0.529396+0.018827	cv-train-auc:0.696911+0.026582
# [11]	cv-test-auc:0.508323+0.039799	cv-train-auc:0.709460+0.022337
# [12]	cv-test-auc:0.512110+0.028811	cv-train-auc:0.721610+0.026933
# [13]	cv-test-auc:0.506857+0.033026	cv-train-auc:0.727527+0.024303
# [14]	cv-test-auc:0.529044+0.039610	cv-train-auc:0.732831+0.026234
# [15]	cv-test-auc:0.518860+0.036271	cv-train-auc:0.737648+0.027005
# [16]	cv-test-auc:0.521277+0.029322	cv-train-auc:0.738349+0.031984
# [17]	cv-test-auc:0.522901+0.030262	cv-train-auc:0.740055+0.029376
# [18]	cv-test-auc:0.517396+0.029386	cv-train-auc:0.742966+0.029508
# [19]	cv-test-auc:0.517302+0.032545	cv-train-auc:0.741657+0.029079
# [20]	cv-test-auc:0.519264+0.024424	cv-train-auc:0.737951+0.032316
# [21]	cv-test-auc:0.514351+0.034589	cv-train-auc:0.742939+0.032154
# [22]	cv-test-auc:0.514139+0.033819	cv-train-auc:0.743217+0.029209
# [23]	cv-test-auc:0.515439+0.025620	cv-train-auc:0.741621+0.031186
# [24]	cv-test-auc:0.513256+0.023399	cv-train-auc:0.746926+0.029044
# [25]	cv-test-auc:0.513825+0.029515	cv-train-auc:0.747467+0.030380
# [26]	cv-test-auc:0.510962+0.029131	cv-train-auc:0.745291+0.025922
# [27]	cv-test-auc:0.505432+0.029086	cv-train-auc:0.746172+0.028829
# [28]	cv-test-auc:0.503765+0.028271	cv-train-auc:0.748617+0.031584
# [29]	cv-test-auc:0.502736+0.029608	cv-train-auc:0.750991+0.030791
# [30]	cv-test-auc:0.501241+0.031247	cv-train-auc:0.751387+0.030300
# [31]	cv-test-auc:0.498825+0.026222	cv-train-auc:0.753446+0.023619
# [32]	cv-test-auc:0.500448+0.024699	cv-train-auc:0.753658+0.022939
# [33]	cv-test-auc:0.503406+0.030167	cv-train-auc:0.753842+0.022098
# [34]	cv-test-auc:0.509814+0.023656	cv-train-auc:0.756251+0.020051
# [35]	cv-test-auc:0.507225+0.021751	cv-train-auc:0.755523+0.019408
# [36]	cv-test-auc:0.510835+0.017788	cv-train-auc:0.761139+0.018680
# [37]	cv-test-auc:0.512184+0.018320	cv-train-auc:0.762706+0.018090
# [38]	cv-test-auc:0.511584+0.022730	cv-train-auc:0.765445+0.019366
# [39]	cv-test-auc:0.507161+0.019254	cv-train-auc:0.764890+0.018430
# [40]	cv-test-auc:0.508164+0.018411	cv-train-auc:0.765421+0.018352
# [41]	cv-test-auc:0.507640+0.015333	cv-train-auc:0.768284+0.016762
# [42]	cv-test-auc:0.511524+0.016100	cv-train-auc:0.769959+0.016416
# [43]	cv-test-auc:0.507381+0.022852	cv-train-auc:0.770297+0.018595
# [44]	cv-test-auc:0.507780+0.022931	cv-train-auc:0.772216+0.021874
# [45]	cv-test-auc:0.508922+0.019175	cv-train-auc:0.771500+0.020981
# [46]	cv-test-auc:0.510518+0.018747	cv-train-auc:0.771681+0.023256
# [47]	cv-test-auc:0.510368+0.018218	cv-train-auc:0.773320+0.019945
# [48]	cv-test-auc:0.516721+0.021763	cv-train-auc:0.775725+0.018859
# [49]	cv-test-auc:0.513355+0.017929	cv-train-auc:0.775409+0.015859
# [50]	cv-test-auc:0.509496+0.012145	cv-train-auc:0.775920+0.018512
# [51]	cv-test-auc:0.510271+0.009040	cv-train-auc:0.775192+0.018334
# [52]	cv-test-auc:0.510247+0.010747	cv-train-auc:0.774685+0.017669
# [53]	cv-test-auc:0.514238+0.010981	cv-train-auc:0.776283+0.016480
# [54]	cv-test-auc:0.513385+0.010556	cv-train-auc:0.778320+0.015824
# [55]	cv-test-auc:0.507744+0.010186	cv-train-auc:0.778123+0.016647
# [56]	cv-test-auc:0.513053+0.009530	cv-train-auc:0.778978+0.015879
# [57]	cv-test-auc:0.509189+0.010354	cv-train-auc:0.781122+0.017695
# [58]	cv-test-auc:0.510431+0.013630	cv-train-auc:0.782157+0.017764
# [59]	cv-test-auc:0.507253+0.013595	cv-train-auc:0.784219+0.016394
# [60]	cv-test-auc:0.507009+0.009414	cv-train-auc:0.782745+0.017455
# [61]	cv-test-auc:0.511345+0.005967	cv-train-auc:0.784834+0.019318
# [62]	cv-test-auc:0.513079+0.002777	cv-train-auc:0.787415+0.019834
# [63]	cv-test-auc:0.513953+0.006957	cv-train-auc:0.789945+0.018070
# [64]	cv-test-auc:0.514401+0.003083	cv-train-auc:0.789578+0.015486
# [65]	cv-test-auc:0.511339+0.005606	cv-train-auc:0.789664+0.017869
# [66]	cv-test-auc:0.509965+0.005348	cv-train-auc:0.788721+0.018503
# [67]	cv-test-auc:0.514196+0.003535	cv-train-auc:0.789477+0.014003
# [68]	cv-test-auc:0.512196+0.004858	cv-train-auc:0.789654+0.015935
# [69]	cv-test-auc:0.515616+0.005364	cv-train-auc:0.791110+0.017506
# [70]	cv-test-auc:0.515781+0.007999	cv-train-auc:0.792999+0.016406
# [71]	cv-test-auc:0.513519+0.008669	cv-train-auc:0.792157+0.015479
# [72]	cv-test-auc:0.514614+0.008825	cv-train-auc:0.794480+0.015343
# [73]	cv-test-auc:0.522435+0.013205	cv-train-auc:0.794402+0.016562
# [74]	cv-test-auc:0.519875+0.008392	cv-train-auc:0.795079+0.011818
# [75]	cv-test-auc:0.518510+0.009115	cv-train-auc:0.794861+0.011865
# [76]	cv-test-auc:0.520100+0.006979	cv-train-auc:0.796559+0.011892
# [77]	cv-test-auc:0.516045+0.008814	cv-train-auc:0.798191+0.011769
# [78]	cv-test-auc:0.514814+0.009565	cv-train-auc:0.800019+0.011333
# [79]	cv-test-auc:0.520364+0.011793	cv-train-auc:0.799823+0.009399
# [80]	cv-test-auc:0.516415+0.013181	cv-train-auc:0.802976+0.008408
# [81]	cv-test-auc:0.515198+0.011218	cv-train-auc:0.802246+0.010815
# [82]	cv-test-auc:0.510443+0.008750	cv-train-auc:0.801890+0.011620
# [83]	cv-test-auc:0.514250+0.014633	cv-train-auc:0.802323+0.012683
# [84]	cv-test-auc:0.517442+0.011712	cv-train-auc:0.803660+0.011469
# [85]	cv-test-auc:0.523029+0.012229	cv-train-auc:0.802624+0.012352
# [86]	cv-test-auc:0.523210+0.012627	cv-train-auc:0.803400+0.014888
# [87]	cv-test-auc:0.520988+0.015812	cv-train-auc:0.803435+0.014722
# [88]	cv-test-auc:0.512818+0.013647	cv-train-auc:0.804450+0.014728
# [89]	cv-test-auc:0.516457+0.010038	cv-train-auc:0.805343+0.013488
# [90]	cv-test-auc:0.518069+0.009997	cv-train-auc:0.806490+0.012121
# [91]	cv-test-auc:0.514764+0.010347	cv-train-auc:0.805900+0.011922
# [92]	cv-test-auc:0.514597+0.011472	cv-train-auc:0.807750+0.010603
# [93]	cv-test-auc:0.515450+0.009644	cv-train-auc:0.807381+0.010436
# [94]	cv-test-auc:0.516756+0.012361	cv-train-auc:0.807605+0.011525
# [95]	cv-test-auc:0.517046+0.012612	cv-train-auc:0.807366+0.013690
# [96]	cv-test-auc:0.515947+0.008026	cv-train-auc:0.809271+0.013463
# [97]	cv-test-auc:0.519993+0.006319	cv-train-auc:0.811088+0.013723
# [98]	cv-test-auc:0.517100+0.011945	cv-train-auc:0.810052+0.014859
# [99]	cv-test-auc:0.512103+0.012321	cv-train-auc:0.812223+0.014101
# [100]	cv-test-auc:0.513744+0.013411	cv-train-auc:0.813145+0.015794
# [101]	cv-test-auc:0.516221+0.015765	cv-train-auc:0.815234+0.014095
# [102]	cv-test-auc:0.514427+0.017535	cv-train-auc:0.816001+0.012707
# [103]	cv-test-auc:0.513294+0.020454	cv-train-auc:0.816055+0.014974
# [104]	cv-test-auc:0.514276+0.018403	cv-train-auc:0.816679+0.016968
# [105]	cv-test-auc:0.513158+0.019353	cv-train-auc:0.816137+0.017210
# [106]	cv-test-auc:0.518810+0.020357	cv-train-auc:0.817067+0.018218
# [107]	cv-test-auc:0.520991+0.018832	cv-train-auc:0.817335+0.020242
# [108]	cv-test-auc:0.520767+0.024568	cv-train-auc:0.818240+0.020179
# [109]	cv-test-auc:0.521228+0.023439	cv-train-auc:0.817011+0.019291
# [110]	cv-test-auc:0.526970+0.025014	cv-train-auc:0.818554+0.019632
# [111]	cv-test-auc:0.528676+0.023571	cv-train-auc:0.820925+0.018029
# [112]	cv-test-auc:0.525877+0.023455	cv-train-auc:0.821765+0.016828
# [113]	cv-test-auc:0.525989+0.024013	cv-train-auc:0.822015+0.017987
# [114]	cv-test-auc:0.525013+0.027301	cv-train-auc:0.823068+0.017314
# [115]	cv-test-auc:0.523532+0.022480	cv-train-auc:0.821617+0.014069
# [116]	cv-test-auc:0.526944+0.023031	cv-train-auc:0.821983+0.013361
# [117]	cv-test-auc:0.525963+0.020847	cv-train-auc:0.821528+0.013449
# [118]	cv-test-auc:0.524947+0.022611	cv-train-auc:0.823987+0.013040
# [119]	cv-test-auc:0.525082+0.022929	cv-train-auc:0.823085+0.011589
# [120]	cv-test-auc:0.522133+0.024372	cv-train-auc:0.824304+0.010442
# [121]	cv-test-auc:0.520320+0.021459	cv-train-auc:0.824971+0.012112
# [122]	cv-test-auc:0.517531+0.020095	cv-train-auc:0.826098+0.012140
# [123]	cv-test-auc:0.516107+0.023260	cv-train-auc:0.827087+0.012171
# [124]	cv-test-auc:0.521265+0.019150	cv-train-auc:0.827175+0.009475
# [125]	cv-test-auc:0.521405+0.022262	cv-train-auc:0.827000+0.007965
# [126]	cv-test-auc:0.522829+0.020168	cv-train-auc:0.827409+0.005761
# [127]	cv-test-auc:0.523543+0.020816	cv-train-auc:0.826820+0.008231
# [128]	cv-test-auc:0.522968+0.020437	cv-train-auc:0.828284+0.009021
# [129]	cv-test-auc:0.522258+0.026832	cv-train-auc:0.827391+0.009166
# [130]	cv-test-auc:0.523932+0.023474	cv-train-auc:0.827430+0.011022
# [131]	cv-test-auc:0.522778+0.027488	cv-train-auc:0.828360+0.010131
# [132]	cv-test-auc:0.521502+0.030407	cv-train-auc:0.828727+0.009384
# [133]	cv-test-auc:0.522353+0.026937	cv-train-auc:0.830433+0.009334
# [134]	cv-test-auc:0.523462+0.026296	cv-train-auc:0.830927+0.009476
# [135]	cv-test-auc:0.523818+0.023848	cv-train-auc:0.831223+0.011164
# [136]	cv-test-auc:0.520779+0.028650	cv-train-auc:0.830395+0.011595
# [137]	cv-test-auc:0.520638+0.025979	cv-train-auc:0.830215+0.012615
# [138]	cv-test-auc:0.522438+0.025960	cv-train-auc:0.832069+0.012495
# [139]	cv-test-auc:0.521264+0.025696	cv-train-auc:0.832239+0.011122
# [140]	cv-test-auc:0.520749+0.024335	cv-train-auc:0.831910+0.012814
# [141]	cv-test-auc:0.522918+0.025716	cv-train-auc:0.831124+0.012688
# [142]	cv-test-auc:0.523136+0.020735	cv-train-auc:0.832128+0.014540
# [143]	cv-test-auc:0.525118+0.022076	cv-train-auc:0.834018+0.014896
# [144]	cv-test-auc:0.526370+0.023510	cv-train-auc:0.832965+0.015441
# [145]	cv-test-auc:0.526625+0.019761	cv-train-auc:0.834764+0.014749
# [146]	cv-test-auc:0.525398+0.020680	cv-train-auc:0.836518+0.013897
# [147]	cv-test-auc:0.525989+0.023292	cv-train-auc:0.836714+0.013725
# [148]	cv-test-auc:0.525305+0.021321	cv-train-auc:0.835921+0.014692
# [149]	cv-test-auc:0.520077+0.024868	cv-train-auc:0.836742+0.016549
# [150]	cv-test-auc:0.521301+0.030070	cv-train-auc:0.838605+0.015335
# [151]	cv-test-auc:0.521475+0.027372	cv-train-auc:0.839457+0.015188
# [152]	cv-test-auc:0.517888+0.030520	cv-train-auc:0.839609+0.015925
# [153]	cv-test-auc:0.520097+0.027545	cv-train-auc:0.839439+0.016095
# [154]	cv-test-auc:0.520886+0.024598	cv-train-auc:0.840220+0.014879
# [155]	cv-test-auc:0.521233+0.028481	cv-train-auc:0.839163+0.015205
# [156]	cv-test-auc:0.526427+0.029126	cv-train-auc:0.838206+0.016201
# [157]	cv-test-auc:0.524503+0.023733	cv-train-auc:0.839168+0.015058
# [158]	cv-test-auc:0.523662+0.026171	cv-train-auc:0.839010+0.015614
# [159]	cv-test-auc:0.527243+0.025041	cv-train-auc:0.837951+0.015910
# [160]	cv-test-auc:0.526599+0.025675	cv-train-auc:0.839541+0.013965
# [161]	cv-test-auc:0.529942+0.029637	cv-train-auc:0.841483+0.012453
# [162]	cv-test-auc:0.525271+0.029615	cv-train-auc:0.842414+0.013488
# [163]	cv-test-auc:0.524158+0.030571	cv-train-auc:0.841830+0.013591
# [164]	cv-test-auc:0.523214+0.030219	cv-train-auc:0.843603+0.013160
# [165]	cv-test-auc:0.528659+0.032879	cv-train-auc:0.843030+0.011697
# [166]	cv-test-auc:0.528080+0.029890	cv-train-auc:0.843935+0.010470
# [167]	cv-test-auc:0.531872+0.028472	cv-train-auc:0.842859+0.010757
# [168]	cv-test-auc:0.533301+0.022856	cv-train-auc:0.842529+0.009051
# [169]	cv-test-auc:0.530826+0.024985	cv-train-auc:0.843503+0.010224
# [170]	cv-test-auc:0.528993+0.027268	cv-train-auc:0.843394+0.011193
# [171]	cv-test-auc:0.527502+0.027205	cv-train-auc:0.843766+0.011937
# [172]	cv-test-auc:0.526310+0.022432	cv-train-auc:0.844331+0.011611
# [173]	cv-test-auc:0.528512+0.023918	cv-train-auc:0.843445+0.013528
# [174]	cv-test-auc:0.526520+0.025488	cv-train-auc:0.841683+0.013439
# [175]	cv-test-auc:0.525668+0.027196	cv-train-auc:0.843597+0.013227
# [176]	cv-test-auc:0.525223+0.025990	cv-train-auc:0.844916+0.012221
# [177]	cv-test-auc:0.523789+0.027114	cv-train-auc:0.844568+0.014679
# [178]	cv-test-auc:0.524729+0.023861	cv-train-auc:0.844812+0.014961
# [179]	cv-test-auc:0.525239+0.024775	cv-train-auc:0.844192+0.015936
# [180]	cv-test-auc:0.525342+0.028932	cv-train-auc:0.844622+0.016160
# [181]	cv-test-auc:0.525177+0.028819	cv-train-auc:0.846110+0.015431
# [182]	cv-test-auc:0.527227+0.028433	cv-train-auc:0.846147+0.015901
# [183]	cv-test-auc:0.529543+0.032290	cv-train-auc:0.846371+0.014847
# [184]	cv-test-auc:0.531343+0.035731	cv-train-auc:0.847359+0.014485
# [185]	cv-test-auc:0.530892+0.031766	cv-train-auc:0.848565+0.014407
# [186]	cv-test-auc:0.531557+0.032952	cv-train-auc:0.850055+0.012045
# [187]	cv-test-auc:0.531380+0.034034	cv-train-auc:0.849376+0.013516
# [188]	cv-test-auc:0.531790+0.032760	cv-train-auc:0.850571+0.013169
# [189]	cv-test-auc:0.533797+0.031616	cv-train-auc:0.851311+0.011836
# [190]	cv-test-auc:0.534516+0.034177	cv-train-auc:0.851144+0.012085
# [191]	cv-test-auc:0.536187+0.033073	cv-train-auc:0.850435+0.010992
# [192]	cv-test-auc:0.537787+0.030938	cv-train-auc:0.852377+0.009601
# [193]	cv-test-auc:0.540491+0.030457	cv-train-auc:0.853141+0.008241
# [194]	cv-test-auc:0.542661+0.032261	cv-train-auc:0.853230+0.009377
# [195]	cv-test-auc:0.541285+0.032018	cv-train-auc:0.854123+0.009697
# [196]	cv-test-auc:0.538168+0.032426	cv-train-auc:0.856837+0.009131
# [197]	cv-test-auc:0.540165+0.029799	cv-train-auc:0.854187+0.009985
# [198]	cv-test-auc:0.538594+0.029927	cv-train-auc:0.853727+0.011156
# [199]	cv-test-auc:0.539312+0.025786	cv-train-auc:0.855810+0.011770
# [200]	cv-test-auc:0.540385+0.022155	cv-train-auc:0.855492+0.013347
# [201]	cv-test-auc:0.541841+0.021060	cv-train-auc:0.855825+0.012016
# [202]	cv-test-auc:0.542618+0.021167	cv-train-auc:0.856486+0.011800
# [203]	cv-test-auc:0.541871+0.017986	cv-train-auc:0.856955+0.012666
# [204]	cv-test-auc:0.540887+0.018717	cv-train-auc:0.856176+0.012601
# [205]	cv-test-auc:0.541760+0.017630	cv-train-auc:0.855736+0.010947
# [206]	cv-test-auc:0.540614+0.018548	cv-train-auc:0.855899+0.012321
# [207]	cv-test-auc:0.536614+0.018633	cv-train-auc:0.856633+0.013917
# [208]	cv-test-auc:0.535978+0.019038	cv-train-auc:0.857289+0.013835
# [209]	cv-test-auc:0.538890+0.021727	cv-train-auc:0.855482+0.013663
# [210]	cv-test-auc:0.537461+0.027284	cv-train-auc:0.857155+0.014456
# [211]	cv-test-auc:0.537140+0.026608	cv-train-auc:0.856610+0.013990
# [212]	cv-test-auc:0.538868+0.024692	cv-train-auc:0.857192+0.014381
# [213]	cv-test-auc:0.540142+0.024855	cv-train-auc:0.858413+0.013631
# [214]	cv-test-auc:0.541718+0.023275	cv-train-auc:0.858148+0.012821
# [215]	cv-test-auc:0.539996+0.023818	cv-train-auc:0.857068+0.012218
# [216]	cv-test-auc:0.539690+0.024611	cv-train-auc:0.858557+0.011972
# [217]	cv-test-auc:0.542939+0.022616	cv-train-auc:0.859275+0.013358
# [218]	cv-test-auc:0.543157+0.024664	cv-train-auc:0.860538+0.014200
# [219]	cv-test-auc:0.542472+0.026856	cv-train-auc:0.861336+0.012139
# [220]	cv-test-auc:0.543936+0.022806	cv-train-auc:0.861143+0.012338
# [221]	cv-test-auc:0.543246+0.022757	cv-train-auc:0.862629+0.013291
# [222]	cv-test-auc:0.544965+0.025534	cv-train-auc:0.862555+0.010568
# [223]	cv-test-auc:0.544937+0.025142	cv-train-auc:0.861433+0.010797
# [224]	cv-test-auc:0.542753+0.025259	cv-train-auc:0.861242+0.009324
# [225]	cv-test-auc:0.544428+0.023356	cv-train-auc:0.860833+0.009636
# [226]	cv-test-auc:0.545322+0.026310	cv-train-auc:0.860989+0.009036
# [227]	cv-test-auc:0.546269+0.024181	cv-train-auc:0.861562+0.008359
# [228]	cv-test-auc:0.546493+0.024063	cv-train-auc:0.860313+0.008134
# [229]	cv-test-auc:0.544577+0.019234	cv-train-auc:0.859635+0.007919
# [230]	cv-test-auc:0.545866+0.018464	cv-train-auc:0.858755+0.009880
# [231]	cv-test-auc:0.546229+0.018707	cv-train-auc:0.859267+0.008779
# [232]	cv-test-auc:0.547887+0.019692	cv-train-auc:0.858386+0.008984
# [233]	cv-test-auc:0.548162+0.016751	cv-train-auc:0.858803+0.009925
# [234]	cv-test-auc:0.547898+0.020121	cv-train-auc:0.860725+0.010258
# [235]	cv-test-auc:0.548753+0.019638	cv-train-auc:0.861760+0.009143
# [236]	cv-test-auc:0.546468+0.019830	cv-train-auc:0.862176+0.011428
# [237]	cv-test-auc:0.546333+0.017471	cv-train-auc:0.863167+0.009488
# [238]	cv-test-auc:0.544362+0.020827	cv-train-auc:0.862942+0.008704
# [239]	cv-test-auc:0.544218+0.020453	cv-train-auc:0.862724+0.009788
# [240]	cv-test-auc:0.544264+0.018066	cv-train-auc:0.863117+0.008811
# [241]	cv-test-auc:0.542388+0.022260	cv-train-auc:0.864336+0.009505
# [242]	cv-test-auc:0.541322+0.023945	cv-train-auc:0.865892+0.009590
# [243]	cv-test-auc:0.547247+0.027351	cv-train-auc:0.863968+0.010106
# [244]	cv-test-auc:0.545033+0.031446	cv-train-auc:0.865566+0.009925
# [245]	cv-test-auc:0.543669+0.030013	cv-train-auc:0.864966+0.009478
# [246]	cv-test-auc:0.546027+0.026879	cv-train-auc:0.865642+0.011370
# [247]	cv-test-auc:0.545585+0.025713	cv-train-auc:0.865875+0.011934
# [248]	cv-test-auc:0.544446+0.021210	cv-train-auc:0.866543+0.011748
# [249]	cv-test-auc:0.543473+0.024247	cv-train-auc:0.867246+0.011384
# [250]	cv-test-auc:0.545486+0.023898	cv-train-auc:0.866430+0.010802
# [251]	cv-test-auc:0.547189+0.026210	cv-train-auc:0.866875+0.011701
# [252]	cv-test-auc:0.549276+0.024524	cv-train-auc:0.866034+0.012901
# [253]	cv-test-auc:0.553472+0.026114	cv-train-auc:0.864616+0.011083
# [254]	cv-test-auc:0.554667+0.023921	cv-train-auc:0.864385+0.010478
# [255]	cv-test-auc:0.553659+0.021648	cv-train-auc:0.864767+0.010112
# [256]	cv-test-auc:0.555405+0.019709	cv-train-auc:0.864651+0.010606
# [257]	cv-test-auc:0.556333+0.017601	cv-train-auc:0.864372+0.010735
# [258]	cv-test-auc:0.555965+0.014624	cv-train-auc:0.864230+0.010400
# [259]	cv-test-auc:0.558891+0.016694	cv-train-auc:0.865750+0.008828
# [260]	cv-test-auc:0.558853+0.017181	cv-train-auc:0.865514+0.008789
# [261]	cv-test-auc:0.560584+0.019229	cv-train-auc:0.866053+0.008082
# [262]	cv-test-auc:0.563501+0.020528	cv-train-auc:0.866228+0.007996
# [263]	cv-test-auc:0.562367+0.023387	cv-train-auc:0.867131+0.008378
# [264]	cv-test-auc:0.562959+0.021840	cv-train-auc:0.868100+0.008593
# [265]	cv-test-auc:0.562107+0.018363	cv-train-auc:0.869182+0.008567
# [266]	cv-test-auc:0.558127+0.018647	cv-train-auc:0.870521+0.008602
# [267]	cv-test-auc:0.558096+0.019267	cv-train-auc:0.869459+0.009375
# [268]	cv-test-auc:0.556578+0.018553	cv-train-auc:0.869944+0.010466
# [269]	cv-test-auc:0.555033+0.018006	cv-train-auc:0.870448+0.010998
# [270]	cv-test-auc:0.554097+0.017820	cv-train-auc:0.870160+0.010874
# [271]	cv-test-auc:0.551598+0.020220	cv-train-auc:0.869781+0.011177
# [272]	cv-test-auc:0.552435+0.019950	cv-train-auc:0.868790+0.011868
# [273]	cv-test-auc:0.556009+0.019567	cv-train-auc:0.868714+0.011427
# [274]	cv-test-auc:0.554993+0.021097	cv-train-auc:0.869055+0.011434
# [275]	cv-test-auc:0.554126+0.021822	cv-train-auc:0.868868+0.010852
# [276]	cv-test-auc:0.556064+0.021957	cv-train-auc:0.869581+0.009638
# [277]	cv-test-auc:0.554768+0.022394	cv-train-auc:0.869628+0.010024
# [278]	cv-test-auc:0.558639+0.020100	cv-train-auc:0.870494+0.010579
# [279]	cv-test-auc:0.560085+0.019188	cv-train-auc:0.872605+0.010642
# [280]	cv-test-auc:0.561899+0.019797	cv-train-auc:0.872916+0.011640
# [281]	cv-test-auc:0.558498+0.020028	cv-train-auc:0.873642+0.011933
# [282]	cv-test-auc:0.556399+0.021511	cv-train-auc:0.872725+0.012196
# [283]	cv-test-auc:0.557443+0.018696	cv-train-auc:0.872706+0.013871
# [284]	cv-test-auc:0.553610+0.019812	cv-train-auc:0.872652+0.013404
# [285]	cv-test-auc:0.554764+0.018965	cv-train-auc:0.873765+0.012112
# [286]	cv-test-auc:0.554773+0.018411	cv-train-auc:0.873634+0.010646
# [287]	cv-test-auc:0.552578+0.019491	cv-train-auc:0.873560+0.010899
# [288]	cv-test-auc:0.549132+0.018808	cv-train-auc:0.872787+0.012093
# [289]	cv-test-auc:0.550499+0.017115	cv-train-auc:0.873908+0.011028
# [290]	cv-test-auc:0.552226+0.019191	cv-train-auc:0.875144+0.010826
# [291]	cv-test-auc:0.552711+0.021780	cv-train-auc:0.875097+0.012087
# [292]	cv-test-auc:0.553216+0.021427	cv-train-auc:0.876907+0.010210
# [293]	cv-test-auc:0.552266+0.020813	cv-train-auc:0.875613+0.011801
# [294]	cv-test-auc:0.551300+0.019316	cv-train-auc:0.877098+0.011207
# [295]	cv-test-auc:0.552519+0.021753	cv-train-auc:0.875909+0.012384
# [296]	cv-test-auc:0.549815+0.020956	cv-train-auc:0.877241+0.012521
# [297]	cv-test-auc:0.550167+0.019461	cv-train-auc:0.876751+0.013228
# [298]	cv-test-auc:0.550269+0.016564	cv-train-auc:0.876838+0.013119
# [299]	cv-test-auc:0.548301+0.015871	cv-train-auc:0.876887+0.013733
# [300]	cv-test-auc:0.547890+0.015891	cv-train-auc:0.878622+0.012776
# [301]	cv-test-auc:0.547198+0.014809	cv-train-auc:0.879224+0.013250
# [302]	cv-test-auc:0.547684+0.016878	cv-train-auc:0.878866+0.014162
# [303]	cv-test-auc:0.547364+0.017808	cv-train-auc:0.879443+0.014119
# [304]	cv-test-auc:0.546825+0.017894	cv-train-auc:0.879537+0.014197
# [305]	cv-test-auc:0.547726+0.016990	cv-train-auc:0.879786+0.013028
# [306]	cv-test-auc:0.546639+0.015433	cv-train-auc:0.879844+0.013617
# [307]	cv-test-auc:0.546999+0.015862	cv-train-auc:0.879715+0.013119
# [308]	cv-test-auc:0.546269+0.017146	cv-train-auc:0.881460+0.012597
# [309]	cv-test-auc:0.549055+0.019324	cv-train-auc:0.882063+0.013809
# [310]	cv-test-auc:0.546682+0.018612	cv-train-auc:0.881767+0.013086
# [311]	cv-test-auc:0.546663+0.017202	cv-train-auc:0.881585+0.012668
# [312]	cv-test-auc:0.549357+0.016737	cv-train-auc:0.883279+0.012305
# [313]	cv-test-auc:0.548610+0.016401	cv-train-auc:0.883196+0.012352
# [314]	cv-test-auc:0.546496+0.016592	cv-train-auc:0.883169+0.012546
# [315]	cv-test-auc:0.544002+0.016910	cv-train-auc:0.881560+0.012684
# [316]	cv-test-auc:0.545964+0.015788	cv-train-auc:0.884097+0.012529
# [317]	cv-test-auc:0.545441+0.013147	cv-train-auc:0.883823+0.013400
# [318]	cv-test-auc:0.545084+0.013200	cv-train-auc:0.882560+0.013524
# [319]	cv-test-auc:0.544508+0.012816	cv-train-auc:0.881261+0.013306
# [320]	cv-test-auc:0.542583+0.014028	cv-train-auc:0.881640+0.013521
# [321]	cv-test-auc:0.546245+0.013364	cv-train-auc:0.881046+0.012653
# [322]	cv-test-auc:0.546663+0.013225	cv-train-auc:0.882676+0.013684
# [323]	cv-test-auc:0.545467+0.012617	cv-train-auc:0.882857+0.012937
# [324]	cv-test-auc:0.549499+0.013422	cv-train-auc:0.882427+0.014383
# [325]	cv-test-auc:0.546765+0.011984	cv-train-auc:0.883486+0.014669
# [326]	cv-test-auc:0.549687+0.010493	cv-train-auc:0.882891+0.015127
# [327]	cv-test-auc:0.550049+0.009773	cv-train-auc:0.882403+0.014740
# [328]	cv-test-auc:0.550484+0.008752	cv-train-auc:0.882200+0.014214
# [329]	cv-test-auc:0.549776+0.010887	cv-train-auc:0.880800+0.015675
# [330]	cv-test-auc:0.549585+0.012317	cv-train-auc:0.881690+0.015433
# [331]	cv-test-auc:0.549829+0.011565	cv-train-auc:0.882042+0.015191
# [332]	cv-test-auc:0.547198+0.011144	cv-train-auc:0.882249+0.013867
# [333]	cv-test-auc:0.548368+0.010578	cv-train-auc:0.882507+0.013608
# [334]	cv-test-auc:0.547273+0.009414	cv-train-auc:0.881872+0.014026
# [335]	cv-test-auc:0.544037+0.011745	cv-train-auc:0.883293+0.014322
# [336]	cv-test-auc:0.547091+0.010348	cv-train-auc:0.883812+0.012722
# [337]	cv-test-auc:0.545310+0.009277	cv-train-auc:0.883731+0.010972
# [338]	cv-test-auc:0.548049+0.010749	cv-train-auc:0.885814+0.011933
# [339]	cv-test-auc:0.551371+0.006864	cv-train-auc:0.884024+0.012293
# [340]	cv-test-auc:0.549022+0.008114	cv-train-auc:0.883715+0.010592
# [341]	cv-test-auc:0.550210+0.008619	cv-train-auc:0.883584+0.011152
# [342]	cv-test-auc:0.551719+0.011372	cv-train-auc:0.882887+0.011352
# [343]	cv-test-auc:0.551393+0.010789	cv-train-auc:0.881714+0.011360
# [344]	cv-test-auc:0.554065+0.011673	cv-train-auc:0.881825+0.012097
# [345]	cv-test-auc:0.554134+0.010252	cv-train-auc:0.881877+0.011563
# [346]	cv-test-auc:0.554798+0.010119	cv-train-auc:0.882473+0.010449
# [347]	cv-test-auc:0.556601+0.012101	cv-train-auc:0.883716+0.010758
# [348]	cv-test-auc:0.554972+0.012040	cv-train-auc:0.884159+0.011761
# [349]	cv-test-auc:0.557042+0.010569	cv-train-auc:0.884069+0.012024
# [350]	cv-test-auc:0.552457+0.010619	cv-train-auc:0.885817+0.013540
# [351]	cv-test-auc:0.553295+0.011575	cv-train-auc:0.886049+0.013643
# [352]	cv-test-auc:0.551974+0.011367	cv-train-auc:0.886429+0.012478
# [353]	cv-test-auc:0.555209+0.011233	cv-train-auc:0.886753+0.013954
# [354]	cv-test-auc:0.552084+0.012926	cv-train-auc:0.887041+0.012421
# [355]	cv-test-auc:0.551605+0.016599	cv-train-auc:0.887531+0.013463
# [356]	cv-test-auc:0.551092+0.014087	cv-train-auc:0.886745+0.014059
# [357]	cv-test-auc:0.551162+0.012823	cv-train-auc:0.887529+0.014574
# [358]	cv-test-auc:0.549964+0.012340	cv-train-auc:0.886175+0.015099
# [359]	cv-test-auc:0.550500+0.012886	cv-train-auc:0.886431+0.013260
# [360]	cv-test-auc:0.547128+0.011365	cv-train-auc:0.886881+0.013995
# [361]	cv-test-auc:0.547626+0.012164	cv-train-auc:0.887244+0.013674
# [362]	cv-test-auc:0.552262+0.012842	cv-train-auc:0.888259+0.013272
# [363]	cv-test-auc:0.550176+0.010491	cv-train-auc:0.888172+0.012579
# [364]	cv-test-auc:0.549299+0.007166	cv-train-auc:0.886749+0.013447
# [365]	cv-test-auc:0.548609+0.009156	cv-train-auc:0.886328+0.011447
# [366]	cv-test-auc:0.549825+0.009416	cv-train-auc:0.887436+0.011073
# [367]	cv-test-auc:0.551580+0.009251	cv-train-auc:0.888764+0.010906
# [368]	cv-test-auc:0.552756+0.009757	cv-train-auc:0.889272+0.010738
# [369]	cv-test-auc:0.552371+0.007931	cv-train-auc:0.889597+0.010785
# [370]	cv-test-auc:0.552684+0.011454	cv-train-auc:0.889692+0.011579
# [371]	cv-test-auc:0.549874+0.011593	cv-train-auc:0.888928+0.009727
# [372]	cv-test-auc:0.548150+0.011157	cv-train-auc:0.889452+0.010063
# [373]	cv-test-auc:0.546298+0.008872	cv-train-auc:0.891545+0.010279
# [374]	cv-test-auc:0.547041+0.007703	cv-train-auc:0.892506+0.010396
# [375]	cv-test-auc:0.547997+0.007115	cv-train-auc:0.892737+0.009524
# [376]	cv-test-auc:0.548843+0.008508	cv-train-auc:0.892231+0.009940
# [377]	cv-test-auc:0.549283+0.006560	cv-train-auc:0.892528+0.011245
# [378]	cv-test-auc:0.551486+0.007316	cv-train-auc:0.891126+0.010038
# [379]	cv-test-auc:0.552612+0.008504	cv-train-auc:0.891159+0.010766
# [380]	cv-test-auc:0.553302+0.009778	cv-train-auc:0.890691+0.010708
# [381]	cv-test-auc:0.551844+0.012504	cv-train-auc:0.890879+0.009414
# [382]	cv-test-auc:0.557644+0.011447	cv-train-auc:0.891636+0.009469
# [383]	cv-test-auc:0.555601+0.010267	cv-train-auc:0.889935+0.009466
# [384]	cv-test-auc:0.558474+0.008020	cv-train-auc:0.890926+0.010059
# [385]	cv-test-auc:0.558973+0.008858	cv-train-auc:0.891400+0.009251
# [386]	cv-test-auc:0.561824+0.010562	cv-train-auc:0.890833+0.009226
# [387]	cv-test-auc:0.556502+0.011366	cv-train-auc:0.890989+0.009258
# [388]	cv-test-auc:0.560261+0.009051	cv-train-auc:0.890874+0.009873
# [389]	cv-test-auc:0.561501+0.009053	cv-train-auc:0.891600+0.010806
# [390]	cv-test-auc:0.558883+0.009479	cv-train-auc:0.891448+0.011348
# [391]	cv-test-auc:0.559398+0.013308	cv-train-auc:0.890988+0.011927
# [392]	cv-test-auc:0.556141+0.014181	cv-train-auc:0.891063+0.012949
# [393]	cv-test-auc:0.554393+0.015268	cv-train-auc:0.890289+0.013926
# [394]	cv-test-auc:0.558615+0.011629	cv-train-auc:0.890929+0.013031
# [395]	cv-test-auc:0.558752+0.011571	cv-train-auc:0.890742+0.012626
# [396]	cv-test-auc:0.557640+0.011694	cv-train-auc:0.891788+0.013565
# [397]	cv-test-auc:0.554798+0.012304	cv-train-auc:0.892647+0.012478
# [398]	cv-test-auc:0.556592+0.012843	cv-train-auc:0.893393+0.012414
# [399]	cv-test-auc:0.558873+0.013131	cv-train-auc:0.893447+0.010866
# [400]	cv-test-auc:0.557917+0.013622	cv-train-auc:0.893394+0.012038
# [401]	cv-test-auc:0.557513+0.015622	cv-train-auc:0.893068+0.013431
# [402]	cv-test-auc:0.554628+0.014831	cv-train-auc:0.894036+0.014337
# [403]	cv-test-auc:0.552473+0.015654	cv-train-auc:0.894475+0.014610
# [404]	cv-test-auc:0.552127+0.014974	cv-train-auc:0.894926+0.014518
# [405]	cv-test-auc:0.553076+0.013181	cv-train-auc:0.894634+0.015165
# [406]	cv-test-auc:0.551031+0.014146	cv-train-auc:0.895021+0.014271
# [407]	cv-test-auc:0.549944+0.014548	cv-train-auc:0.893888+0.015334
# [408]	cv-test-auc:0.548564+0.016700	cv-train-auc:0.894547+0.014565
# [409]	cv-test-auc:0.548813+0.014068	cv-train-auc:0.894519+0.013944
# [410]	cv-test-auc:0.553233+0.014845	cv-train-auc:0.894008+0.014031
# [411]	cv-test-auc:0.552068+0.010745	cv-train-auc:0.894404+0.012992
# [412]	cv-test-auc:0.550247+0.014126	cv-train-auc:0.895454+0.012603
# [413]	cv-test-auc:0.552148+0.011673	cv-train-auc:0.894919+0.012806
# [414]	cv-test-auc:0.552753+0.012397	cv-train-auc:0.895587+0.012419
# [415]	cv-test-auc:0.553805+0.016617	cv-train-auc:0.896650+0.013444
# [416]	cv-test-auc:0.554622+0.017641	cv-train-auc:0.896448+0.014127
# [417]	cv-test-auc:0.555635+0.015379	cv-train-auc:0.896296+0.014024
# [418]	cv-test-auc:0.554139+0.014740	cv-train-auc:0.895960+0.012876
# [419]	cv-test-auc:0.552183+0.017563	cv-train-auc:0.896933+0.012608
# [420]	cv-test-auc:0.550241+0.018234	cv-train-auc:0.896782+0.011377
# [421]	cv-test-auc:0.549489+0.016400	cv-train-auc:0.896750+0.011075
# [422]	cv-test-auc:0.549245+0.016393	cv-train-auc:0.897011+0.011453
# [423]	cv-test-auc:0.552044+0.015713	cv-train-auc:0.895973+0.011568
# [424]	cv-test-auc:0.554311+0.015573	cv-train-auc:0.895837+0.010983
# [425]	cv-test-auc:0.552919+0.016552	cv-train-auc:0.896459+0.010309
# [426]	cv-test-auc:0.554967+0.017826	cv-train-auc:0.895327+0.010356
# [427]	cv-test-auc:0.553872+0.018755	cv-train-auc:0.896631+0.009904
# [428]	cv-test-auc:0.553081+0.021222	cv-train-auc:0.896868+0.009844
# [429]	cv-test-auc:0.555778+0.020488	cv-train-auc:0.897921+0.009087
# [430]	cv-test-auc:0.554320+0.021914	cv-train-auc:0.897868+0.009764
# [431]	cv-test-auc:0.555774+0.020480	cv-train-auc:0.897998+0.009291
# [432]	cv-test-auc:0.553513+0.020703	cv-train-auc:0.897091+0.009432
# [433]	cv-test-auc:0.553257+0.021547	cv-train-auc:0.898487+0.010221
# [434]	cv-test-auc:0.555227+0.022819	cv-train-auc:0.897892+0.010337
# [435]	cv-test-auc:0.554743+0.022701	cv-train-auc:0.898100+0.011129
# [436]	cv-test-auc:0.555693+0.022775	cv-train-auc:0.896797+0.010630
# [437]	cv-test-auc:0.557237+0.021578	cv-train-auc:0.896365+0.009846
# [438]	cv-test-auc:0.556647+0.023265	cv-train-auc:0.896588+0.009400
# [439]	cv-test-auc:0.553118+0.022074	cv-train-auc:0.896423+0.011007
# [440]	cv-test-auc:0.553048+0.020784	cv-train-auc:0.896555+0.010103
# [441]	cv-test-auc:0.551809+0.018851	cv-train-auc:0.896776+0.010163
# [442]	cv-test-auc:0.550770+0.019955	cv-train-auc:0.896813+0.008935
# [443]	cv-test-auc:0.549032+0.022160	cv-train-auc:0.898187+0.010286
# [444]	cv-test-auc:0.548087+0.020523	cv-train-auc:0.899388+0.009101
# [445]	cv-test-auc:0.546561+0.022373	cv-train-auc:0.898216+0.009109
# [446]	cv-test-auc:0.547481+0.021971	cv-train-auc:0.897063+0.010035
# [447]	cv-test-auc:0.545835+0.023539	cv-train-auc:0.898496+0.008251
# [448]	cv-test-auc:0.546866+0.020801	cv-train-auc:0.898536+0.008985
# [449]	cv-test-auc:0.544962+0.022963	cv-train-auc:0.898984+0.009080
# [450]	cv-test-auc:0.549268+0.022573	cv-train-auc:0.898149+0.010848
# [451]	cv-test-auc:0.549059+0.023464	cv-train-auc:0.898643+0.009905
# [452]	cv-test-auc:0.546082+0.019599	cv-train-auc:0.898655+0.009787
# [453]	cv-test-auc:0.547645+0.017760	cv-train-auc:0.898774+0.010291
# [454]	cv-test-auc:0.550082+0.018524	cv-train-auc:0.897528+0.009693
# [455]	cv-test-auc:0.548348+0.019409	cv-train-auc:0.898618+0.008727
# [456]	cv-test-auc:0.549604+0.018112	cv-train-auc:0.898683+0.008418
# [457]	cv-test-auc:0.552501+0.017768	cv-train-auc:0.899030+0.009228
# [458]	cv-test-auc:0.552053+0.017218	cv-train-auc:0.897500+0.009834
# [459]	cv-test-auc:0.548751+0.018318	cv-train-auc:0.897259+0.011071
# [460]	cv-test-auc:0.547875+0.019546	cv-train-auc:0.896377+0.011294
# [461]	cv-test-auc:0.549664+0.019550	cv-train-auc:0.897577+0.012250
# [462]	cv-test-auc:0.546020+0.020635	cv-train-auc:0.897118+0.012996
# [463]	cv-test-auc:0.549351+0.020106	cv-train-auc:0.897000+0.013024
# [464]	cv-test-auc:0.549612+0.017689	cv-train-auc:0.898309+0.013188
# [465]	cv-test-auc:0.550097+0.019496	cv-train-auc:0.897630+0.012803
# [466]	cv-test-auc:0.552099+0.018395	cv-train-auc:0.898006+0.012456
# [467]	cv-test-auc:0.550687+0.019715	cv-train-auc:0.898693+0.011534
# [468]	cv-test-auc:0.549045+0.018065	cv-train-auc:0.900321+0.011743
# [469]	cv-test-auc:0.551702+0.019901	cv-train-auc:0.899339+0.011485
# [470]	cv-test-auc:0.551638+0.020484	cv-train-auc:0.898651+0.011056
# [471]	cv-test-auc:0.550207+0.019213	cv-train-auc:0.899614+0.010094
# [472]	cv-test-auc:0.552227+0.020333	cv-train-auc:0.899087+0.009627
# [473]	cv-test-auc:0.549306+0.022695	cv-train-auc:0.900051+0.008417
# [474]	cv-test-auc:0.550322+0.021797	cv-train-auc:0.900246+0.009139
# [475]	cv-test-auc:0.549895+0.023770	cv-train-auc:0.900973+0.009554
# [476]	cv-test-auc:0.545495+0.024192	cv-train-auc:0.900549+0.009647
# [477]	cv-test-auc:0.545714+0.025751	cv-train-auc:0.900836+0.008692
# [478]	cv-test-auc:0.548701+0.022973	cv-train-auc:0.900431+0.008332
# [479]	cv-test-auc:0.547869+0.019857	cv-train-auc:0.899217+0.007716
# [480]	cv-test-auc:0.547548+0.019630	cv-train-auc:0.900814+0.007867
# [481]	cv-test-auc:0.547435+0.018887	cv-train-auc:0.900302+0.007616
# [482]	cv-test-auc:0.546933+0.017726	cv-train-auc:0.900685+0.007894
# [483]	cv-test-auc:0.548737+0.016506	cv-train-auc:0.902042+0.007615
# [484]	cv-test-auc:0.548528+0.015702	cv-train-auc:0.901127+0.008134
# [485]	cv-test-auc:0.547724+0.015575	cv-train-auc:0.901429+0.009346
# [486]	cv-test-auc:0.548859+0.016192	cv-train-auc:0.901588+0.009320
# [487]	cv-test-auc:0.549176+0.017877	cv-train-auc:0.901948+0.009322
# [488]	cv-test-auc:0.546149+0.018069	cv-train-auc:0.901487+0.011117
# [489]	cv-test-auc:0.545151+0.018107	cv-train-auc:0.902698+0.010275
# [490]	cv-test-auc:0.549002+0.017948	cv-train-auc:0.902812+0.010125
# [491]	cv-test-auc:0.548023+0.016589	cv-train-auc:0.902405+0.008793
# [492]	cv-test-auc:0.546652+0.018046	cv-train-auc:0.902783+0.008169
# [493]	cv-test-auc:0.548320+0.017346	cv-train-auc:0.901864+0.008964
# [494]	cv-test-auc:0.548397+0.016365	cv-train-auc:0.901930+0.010744
# [495]	cv-test-auc:0.546238+0.016372	cv-train-auc:0.902368+0.010368
# [496]	cv-test-auc:0.546602+0.018991	cv-train-auc:0.901820+0.010255
# [497]	cv-test-auc:0.545265+0.019304	cv-train-auc:0.901149+0.010354
# [498]	cv-test-auc:0.543451+0.019252	cv-train-auc:0.902361+0.010599
# [499]	cv-test-auc:0.542342+0.018940	cv-train-auc:0.902367+0.010541

# %% [markdown]
# #Testing Keras

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import PReLU
from keras.utils import np_utils, generic_utils
from keras.optimizers import Adadelta
from keras.regularizers import l1, l2, l1l2

y_enc = np_utils.to_categorical(y)

# %%
prepipe = make_pipeline(
    make_union(
        IdentityTformer(),
#         AnscombeTformer(),
        make_pipeline(AddTformer(1), BoxCoxTformer()),
    ), StandardScaler(),
)

X_post = prepipe.fit_transform(X)

# %%
X_post.shape
# Out:
# (2013, 84)

# %%
def build_model(input_dim, output_dim):
    model = Sequential()
    model.add(Dropout(0.4))
    model.add(Dense(input_dim, 256, init='he_uniform', W_regularizer = l1l2(l1=5e-5, l2=1e-5)))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))

    model.add(Dense(256, 256, init='he_uniform', W_regularizer = l1l2(l1=5e-5, l2=1e-5)))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))

    model.add(Dense(256, 256, init='he_uniform', W_regularizer = l1l2(l1=5e-5, l2=1e-5)))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))

    model.add(Dense(256, output_dim, init='he_uniform', W_regularizer = l1l2(l1=5e-5, l2=1e-5)))
    model.add(Activation('softmax'))

    adadelta = Adadelta(lr=1.0, rho=0.95, epsilon=1e-6)
    model.compile(loss='categorical_crossentropy', optimizer='rmsprop')
    return model

# def build_model(input_dim, output_dim):
#     model = Sequential()
#     model.add(Dropout(0.4))
#     model.add(Dense(input_dim, 256, init='he_uniform', W_regularizer = l1l2(l1=5e-5, l2=1e-5)))
#     model.add(Activation('relu'))
#     model.add(Dropout(0.5))

#     model.add(Dense(256, 256, init='he_uniform', W_regularizer = l1l2(l1=5e-5, l2=1e-5)))
#     model.add(Activation('relu'))
#     model.add(Dropout(0.5))

#     model.add(Dense(256, 256, init='he_uniform', W_regularizer = l1l2(l1=5e-5, l2=1e-5)))
#     model.add(Activation('relu'))
#     model.add(Dropout(0.5))

#     model.add(Dense(256, output_dim, init='he_uniform', W_regularizer = l1l2(l1=5e-5, l2=1e-5)))
#     model.add(Activation('softmax'))

#     adadelta = Adadelta(lr=1.0, rho=0.95, epsilon=1e-6)
#     model.compile(loss='categorical_crossentropy', optimizer='rmsprop')
#     return model

# %%
scores_keras = []
losses_list = []
for ii, (train, valid) in enumerate(skf):
    print('---'*20)
    print('Fold', ii)
    print('---'*20)
    X_train = X_post[train]
    X_valid = X_post[valid]
    Y_train = y_enc[train]
    Y_valid = y_enc[valid]
    y_valid = y[valid]
    
    print("Building model...")
    dims = X_train.shape[1]
    nb_classes = y_enc.shape[1]
    model = build_model(dims, nb_classes)

    print("Training model...")

    losses_list.append(model.fit(X_train, Y_train, nb_epoch=2000, batch_size=512, 
                                 validation_data=(X_valid, Y_valid), verbose=0))
    valid_preds = model.predict_proba(X_valid, verbose=0)
    valid_preds = valid_preds[:, 1]
    roc = roc_auc_score(y_valid, valid_preds)
    print("ROC:", roc)
    scores_keras.append(roc)
    
#     break
# Out:
# ------------------------------------------------------------
# ('Fold', 0)
# ------------------------------------------------------------
# Building model...
# Training model...
# ('ROC:', 0.91221435468297396)
# ------------------------------------------------------------
# ('Fold', 1)
# ------------------------------------------------------------
# Building model...
# Training model...
# ('ROC:', 0.8718216929514)
# ------------------------------------------------------------
# ('Fold', 2)
# ------------------------------------------------------------
# Building model...
# Training model...
# ('ROC:', 0.85804708917916472)
# ------------------------------------------------------------
# ('Fold', 3)
# ------------------------------------------------------------
# Building model...
# Training model...
# ('ROC:', 0.83090146750524108)

# %%
# qq = np.min(score['val_loss'])

# %%
plt.figure(figsize=(20,10))
for score in losses_list:
    plt.plot(score['val_loss'])

plt.ylim([0.1, 0.16])
plt.plot([0, len(score['val_loss'])], [q, q])
plt.plot([0, len(score['val_loss'])], [qq, qq])

# %%
np.mean(scores_keras)
# Out:
# 0.85685264861451016

# %%
# valid_preds
valid_preds[np.where(y_valid)]

# %% [markdown]
# # Prediction

# %% [markdown]
# ## Ok, train first

# %%
clf_et = ExtraTreesClassifier(bootstrap=False, 
                           min_samples_leaf=8,
                           n_estimators=200,
                           min_samples_split=7,
                           criterion='entropy',
                           max_features=30,
                           max_depth=None,
                           n_jobs=-1,
                          )
clf_adab = AdaBoostClassifier(n_estimators=50, learning_rate=0.15)
# clf_bc = BaggingClassifier(n_estimators=500,
#                         bootstrap_features=True,
#                         max_samples=1.0,
#                         max_features=0.9,
#                         n_jobs=-1)

pipe_et = make_pipeline(make_union(
        IdentityTformer(), make_pipeline(AddTformer(1), BoxCoxTformer()),
    ), clf_et)
pipe_adab = make_pipeline(make_union(
        IdentityTformer(), make_pipeline(AddTformer(1), BoxCoxTformer()),
    ), clf_adab)


# pipes = [pipe_et, pipe_adab]
pipes = [pipe_et]

for pipe in pipes:
    pipe.fit(X, y)
# clf_bc.fit(X, y)

# %% [markdown]
# ## Setup test obs

# %%
sub = pd.read_csv('../data/sampleSubmission.csv')
test_bidders = [bidders_d[test_id] for test_id in sub['bidder_id']]
len(test_bidders)
# Out:
# 4700

# %%
X1_test = [snipe_feats[b.bidder_id] for b in test_bidders]
X2_test = BidsPerAuct().transform(test_bidders)
X3_test = [diversity_feats[b.bidder_id] for b in test_bidders]

X4_test = [count_feats[b.bidder_id] for b in test_bidders]

X5_1_test = [peak_feats[b.bidder_id] for b in test_bidders]
X5_2_test = [peak_feats5e9[b.bidder_id] for b in test_bidders]
X5_3_test = [peak_feats2e10[b.bidder_id] for b in test_bidders]
X5_4_test = [peak_feats1e11[b.bidder_id] for b in test_bidders]


X_test = np.c_[X2_test, X3_test, np.array(X4_test)[:, keep_inds],
               X5_1_test, X5_2_test, X5_3_test, X5_4_test]

# %%
np.save('../data/X_test.npy', X_test)

# %%
y_pred_list = []
for pipe in pipes:
    y_pred_list.append(pipe.predict_proba(X_test)[:, 1])

# y_pred_1 = pipe1.predict_proba(X_test)[:, 1]
# y_pred_2 = pipe2.predict_proba(X_test)[:, 1]
# y_pred_bc = clf_bc.predict_proba(X_test)[:, 1]

# y_pred_avg = np.array([y_pred_et, y_pred_adab, y_pred_bc]).mean(axis=0)
y_pred_avg = np.array(y_pred_list).mean(axis=0)

# %%
plt.figure(figsize=(20,10))
# plt.plot(np.array([y_pred_et, y_pred_adab, y_pred_bc]).T)
plt.plot(np.array(y_pred_list).T)

# %%
(y_pred_avg>0.6).sum()
# Out:
# 3

# %%
sub['prediction'] = y_pred_avg

# %%
sub.to_csv('../submissions/et_withdevicecountry-boxcox.csv', index=False)

# %%
plt.scatter(range(len(clf_et.feature_importances_)), clf_et.feature_importances_)

# %%
plt.hist(y_pred_avg)
# Out:
# (array([ 3840.,   395.,   176.,   100.,    67.,    29.,    32.,    40.,
#            17.,     4.]),
#  array([ 0.        ,  0.07589705,  0.15179411,  0.22769116,  0.30358821,
#          0.37948527,  0.45538232,  0.53127938,  0.60717643,  0.68307348,
#          0.75897054]),
#  <a list of 10 Patch objects>)
